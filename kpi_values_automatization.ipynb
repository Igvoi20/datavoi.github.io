# %%
import requests 
import json
import pandas as pd
import numpy as np
import datetime  
import matplotlib as plt
import io
from statistics import mean 
import statistics 
from datetime import date
import io
import re
import datetime
import requests
from urllib.parse import urlencode
import time
from google.oauth2 import service_account
import stripe 
import df2gspread as d2g
import nltk
import json
from difflib import SequenceMatcher
import datetime  
import matplotlib as plt
from df2gspread import df2gspread as d2g
import gspread
import datetime
import numpy as np
import requests
#from oauth2client.service_account import ServiceAccountCredentials
import pygsheets
import pandas as pd
import requests as req
from datetime import datetime, timedelta
import datetime  
import plotly.express as px
from bs4 import BeautifulSoup
#from pandas.tseries.offsets import MonthEnd
import requests
import json
import df2gspread as d2g
from datetime import datetime
import pygsheets
import psycopg2
from datetime import datetime
from datetime import date
import datetime
import requests
import json
import pandas.io.sql as sqlio
import psycopg2.extras
from psycopg2.extensions import register_adapter
import datetime
#today = date.today()
#today = today.strftime("%d/%m/%Y")
#print("Today's date:", today)
import datetime
Previous_Date = datetime.datetime.today() - datetime.timedelta(days=2)
today = Previous_Date.strftime("%d/%m/%Y")

# %%
today = datetime.date.today()
first = today.replace(day=1)
lastMonth = first - datetime.timedelta(days=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-7081c0737f3c> in <module>
# ----> 1 today = datetime.date.today()
#       2 first = today.replace(day=1)
#       3 lastMonth = first - datetime.timedelta(days=1)
#       4 print(lastMonth.strftime("%m-%Y"))
#
# AttributeError: 'method_descriptor' object has no attribute 'today'

# %%
# получаем доступы их platform ops token, users, kpi_id, user_id

# %%
access_token='eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjE0NjIxMDEwLCJqdGkiOiJkMmYzZTY3YmE1MzQ0OTY2YjRlYzEwMTM2OTM4MjQ1NyIsInVzZXJfaWQiOjI2MH0.v4jw6U7G9LEL9EwTB4iqiY-M1JxcXw5tTnkl_SO0sr0'
import requests

headers = {
    'email': 'igor.voinyak@latoken.com',
    'password': '.>.2]{x7Dm',
    "content-type":"application/json"
}

response = requests.post('https://new.la-team.tk/api/auth/login/', data=headers)
access_token=response.json()
token=access_token['access_token']

# %%
headers = {
    'email': 'igor.voinyak@latoken.com',
    'password': '.>.2]{x7Dm',
    "content-type":"application/json"
}
response = requests.post('https://new.la-team.tk/api/auth/login/', data=headers)
access_token=response.json()
token=access_token['access_token']
#token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNjE2MzQwMTk3LCJqdGkiOiIyMjRhM2QxODczOGU0NjgyODA3YWUyNWNjODAzYTNkYiIsInVzZXJfaWQiOjI2MH0.41FX8shPm4EFUDr7lg_RzPeNVl0Tsqy27s6ZZz9p7Qk'
bearer_token = 'Bearer '+ token
header = {'Authorization': bearer_token}
url = 'http://new.la-team.tk/api/kpi-coefficient-values/?start_date=2021-02-01&end_date=2021-02-28'
r = requests.get(url, headers=header)
response = r.json()

# %%
#users json for request post
bearer_token = 'Bearer '+ token
header = {'Authorization': bearer_token}
url = 'https://new.la-team.tk/api/auth/accounts?is_active=True'
r = requests.get(url, headers=header)
r.json()
users_json = r.json()
users = pd.json_normalize(users_json)
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
            "Content-Type":"application/json"}
url = 'https://ops-frontend.dev3.nekotal.tech/api/kpi-coefficient-values/'
#url = 'https://ops-frontend.dev3.nekotal.tech/api/kpi-coefficient-values/'

# %%
#extract kpi data
bearer_token = 'Bearer '+ token
header = {'Authorization': bearer_token}
url = 'https://new.la-team.tk/api/kpi-coefficient-types'
r = requests.get(url, headers=header)
kpi_json =r.json()
kpi = pd.json_normalize(kpi_json)

# %%
#extract kpi value
bearer_token = 'Bearer '+ token
header = {'Authorization': bearer_token}
url = 'https://new.la-team.tk/api/kpi-coefficient-types'
r = requests.get(url, headers=header)
kpi_json =r.json()
kpi = pd.json_normalize(kpi_json)

# %%
headers = {
    'email': 'igor.voinyak@latoken.com',
    'password': '.>.2]{x7Dm',
    "content-type":"application/json"
}
response = requests.post('https://new.la-team.tk/api/auth/login/', data=headers)
access_token=response.json()
token=access_token['access_token']
bearer_token = 'Bearer '+ token
header = {'Authorization': bearer_token}
url = 'https://new.la-team.tk/api/auth/accounts?is_active=True'
r = requests.get(url, headers=header)
users_json = r.json()

# %%
for j in range(len(users_json)):
    if (users_json[j]['email']== 'pavel.pilikin@latoken.com'):
        denis_dvoryankin_id = j
denis_dvoryankin_id
# Out:
# 102

# %%
#Top_30_Spread_success and Top_2_Spread_success ничего не нужно добавлять автоматизированно на 100%
def return_coda_is_rows(url):
    headers = {'Authorization': 'Bearer 9175cdcc-32f3-469b-abfe-680914bad093'}
    uri = 'https://coda.io/apis/v1/resolveBrowserLink'
    params = {
      'url': url    }
    res = requests.get(uri, headers=headers, params=params).json()
    resolved_uri = res["resource"]["href"]
    res = requests.get(resolved_uri, headers=headers).json()
    #print(f'This link points to a {res["type"]} named {res["name"]}')
    return res['values']


# => This link points to a table named To-do List

#///////////////////////////////////////////////////////////////////
#now = datetime.now() # current date and time
# Autorization Coda
coda_token = '9175cdcc-32f3-469b-abfe-680914bad093' # Coda token
headers = {'Authorization': f'Bearer {coda_token}'}
#headers = {'Authorization': 'Bearer <your token id>'}#insert your token id instead of 
url = f'https://coda.io/apis/v1/docs/iCAmiFZp3V/tables/grid-WRXRPvlKGg/rows'

req = requests.get(url, headers=headers)
req.raise_for_status() # Throw if there was an error.
res = req.json()
#Top_30_Spread_success=res['items'][183]['values']
#Top_2_Spread_success=res['items'][182]['values']

Top_30_Spread_success = return_coda_is_rows('https://coda.io/d/OKRs-Sync_diCAmiFZp3V/OKRs-performance_sumTJ?utm_source=slack#OKRs-performance_tuKGg/r296')
Top_2_Spread_success = return_coda_is_rows('https://coda.io/d/OKRs-Sync_diCAmiFZp3V/OKRs-performance_sumTJ?utm_source=slack#OKRs-performance_tuKGg/r295')
Top_30_Spread_success = [(k, v) for k, v in Top_30_Spread_success.items()] 
Top_2_Spread_success = [(k, v) for k, v in Top_2_Spread_success.items()] 
Top_30_Spread_success = Top_30_Spread_success[52:-4] # провереть если собирает все показатели из coda  4 цифр за месяц по неделям
Top_2_Spread_success = Top_2_Spread_success[52:-4]
Top_2_Spread_success = [item for t in Top_2_Spread_success for item in t] 
Top_30_Spread_success = [item for t in Top_30_Spread_success for item in t]
Top_30_Spread_success_sum = sum([x for x in Top_30_Spread_success if isinstance(x, float)]) 
Top_30_Spread_success_sum=Top_30_Spread_success_sum/4
Top_2_Spread_success_sum = 0
for item in Top_2_Spread_success: 
    try: 
        Top_2_Spread_success_sum+= float(item) 
    except ValueError: 
        pass
Top_2_Spread_success_sum = Top_2_Spread_success_sum/4
all_sum=round(((Top_2_Spread_success_sum+Top_30_Spread_success_sum)/2)/100,2)

for j in range(len(users_json)):
    if (users_json[j]['email']== 'dmitry.myasin@latoken.com'):# его нет в базе
        nkin_id = j


data = {
    #"user":users_json[nkin_id],
    "description": 'Time on target',
    "value": all_sum,
    "date": today,
    "kpi_type": 10, #Time on target
    "unit": ["Trading Desk"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://ops-frontend.dev3.nekotal.tech/api/kpi-coefficient-values/' # https://new.la-team.tk
r = requests.post(url, headers=headers, data=data)

# %%
# ниже не использовать, не правильные данные  автоматизированно на 100%

# %%
#listing kpi = 'выручка каждого Listing менеджера за период' сумма по всем = 'Revenue Listings, $'
register_adapter(dict, psycopg2.extras.Json) 
db_host = '135.181.61.116'
db_port = '5432'
connection = psycopg2.connect(dbname='postgres', user='crm_listings', 
                        password='', host='135.181.61.116', port = db_port)
cursor = connection.cursor()

##sql = "select distinct task #>> '{unit}' as unit, (case when is_critical = true then count(is_critical) end) as count from platform.checklist
##group by checklist.task, checklist.is_critical %s" % tablename
cursor.execute('''create table cold_sales_1 as
select * from crm.event
where (value_before='{"{\"lead_status\": {\"id\": 21050272, \"pipeline_id\": 1289332}}"}')
and (value_after='{"{\"lead_status\": {\"id\": 21050275, \"pipeline_id\": 1289332}}"}');
create table hot_sales_1 as
select * from crm.event
where (value_before='{"{\"lead_status\": {\"id\": 21050275, \"pipeline_id\": 1289332}}"}')
and (value_after='{"{\"lead_status\": {\"id\": 35522263, \"pipeline_id\": 1289332}}"}');
create table cold_to_hot as
select
c.name,
c.status_id,
c.updated_at,
c.closed_at,
a.entity_id,
c.responsible_user_id
(b.created_at - a.created_at) from cold_sales_1 a
inner join hot_sales_1 b on (a.entity_id=b.entity_id)
left join crm.lead c on (c.id=a.entity_id)
left join crm.user d on (c.responsible_user_id=d.id);''')

result = cursor.fetchall()
for item in result:
    print (itуь)
# col_names = []
# for elt in cursor.description:
#     col_names.append(elt[0])
# df_crm_listings =pd.DataFrame(np.array(result), columns=col_names)
if (connection):
    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# <ipython-input-3-3133609a4743> in <module>
#       9 ##sql = "select distinct task #>> '{unit}' as unit, (case when is_critical = true then count(is_critical) end) as count from platform.checklist
#      10 ##group by checklist.task, checklist.is_critical %s" % tablename
# ---> 11 cursor.execute('''create table cold_sales_1 as
#      12 select * from crm.event
#      13 where (value_before='{"{\"lead_status\": {\"id\": 21050272, \"pipeline_id\": 1289332}}"}')
#
# InvalidTextRepresentation: malformed array literal: "{"{"lead_status": {"id": 21050272, "pipeline_id": 1289332}}"}"
# LINE 3: where (value_before='{"{"lead_status": {"id": 21050272, "pip...
#                             ^
# DETAIL:  Unexpected array element.

# %%
#///////next kpi  автоматизированно на 100% не использовать не правильные данные!

# %%
#listing kpi = 'выручка каждого Listing менеджера за период' сумма по всем = 'Revenue Listings, $'
register_adapter(dict, psycopg2.extras.Json) 
db_host = '135.181.61.116'
db_port = '5432'
connection = psycopg2.connect(dbname='postgres', user='crm_listings', 
                        password=' ', host='135.181.61.116', port = db_port)
cursor = connection.cursor()

##sql = "select distinct task #>> '{unit}' as unit, (case when is_critical = true then count(is_critical) end) as count from platform.checklist
##group by checklist.task, checklist.is_critical %s" % tablename
cursor.execute('''select
distinct (l.id) as lead_id,
l.name as project_name,
tn.token_name,
of.order_form,
u.name,
rc.responsible_updated::timestamp::date as responsible_changed,
l.price::decimal as invoiced_amount,
COALESCE(p1.pay1::decimal,0) + COALESCE(p2.pay2::decimal,0) + COALESCE(p3.pay3::decimal,0) + COALESCE(p4.pay4::decimal,0)
 + COALESCE(p5.pay5::decimal,0) + COALESCE(p6.pay6::decimal,0) as paid_amount,
(l.price::decimal- COALESCE(p1.pay1::decimal,0) - COALESCE(p2.pay2::decimal,0) - COALESCE(p3.pay3::decimal,0)
- COALESCE(p4.pay4::decimal,0) - COALESCE(p5.pay5::decimal,0) - COALESCE(p6.pay6::decimal,0) ) as debt_amount,

lg.leadgen_manager as leadgen_manager,

lsc.status_changed as status_changed_at
from crm.lead l
join crm.user u on (u.id = l.responsible_user_id)

left join (select
    l.id as lead_id,
    m.e#>>'{values,0,value}' as token_name
    from crm.lead l,
         lateral (select unnest(custom_fields_values) e)m
    where m.e#>> '{field_name}'='Token name') tn on (tn.lead_id=l.id)

left join (select
    l.id as lead_id,
    m.e#>>'{values,0,value}' as order_form
    from crm.lead l,
         lateral (select unnest(custom_fields_values) e)m
    where m.e#>> '{field_name}'='Order Form Company Name') of on (of.lead_id=l.id)

left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as responsible_updated,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    where e.type = 'entity_responsible_changed') w
            where w.rn = 1) rc on (rc.lead_id=l.id)


left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as status_changed,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    where e.type = 'lead_status_changed') w
            where w.rn = 1) lsc on (lsc.lead_id=l.id)

left join (select l.id,
                a.e#>>'{values,0,value}' as pay1,
                l.status_id
                from crm.lead l,
                lateral (select unnest(custom_fields_values) e) a
                where a.e#>> '{field_name}'='Payment #1 (USDT)') p1 on (p1.id=l.id)
left join (select l.id,
            a.e#>>'{values,0,value}' as pay2,
            l.status_id
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) a
            where a.e#>> '{field_name}'='Payment #2 (USDT)') p2 on (p2.id=l.id)
left join (select l.id,
            a.e#>>'{values,0,value}' as pay3,
            l.status_id
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) a
            where a.e#>> '{field_name}'='Payment #3 (USDT)') p3 on (p3.id=l.id)
left join (select l.id,
            a.e#>>'{values,0,value}' as pay4,
            l.status_id
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) a
            where a.e#>> '{field_name}'='Payment #4 (USDT)') p4 on (p4.id=l.id)
left join (select l.id,
            a.e#>>'{values,0,value}' as pay5,
            l.status_id
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) a
            where a.e#>> '{field_name}'='Payment #5 (USDT)') p5 on (p5.id=l.id)
left join (select l.id,
            a.e#>>'{values,0,value}' as pay6,
            l.status_id
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) a
            where a.e#>> '{field_name}'='Payment #6 (USDT)') p6 on (p6.id=l.id)


left join (select l.id,
            m.e#>>'{values,0,value}' as leadgen_manager
            from crm.lead l,
            lateral (select unnest(custom_fields_values) e) m
            where m.e#>> '{field_name}'='LeadGen manager') lg on (lg.id=l.id)

where l.pipeline_id = 1289332
and l.is_deleted = false
and (l.status_id=29091508 or l.status_id=142)
and u.rights#>> '{role_id}' = 269443::text
and u.rights#>> '{is_active}' = true::text
and lsc.status_changed>'2020-12-31'
--and COALESCE(p1.pay1::decimal,0) + COALESCE(p2.pay2::decimal,0) + COALESCE(p3.pay3::decimal,0) + COALESCE(p4.pay4::decimal,0)
-- + COALESCE(p5.pay5::decimal,0) + COALESCE(p6.pay6::decimal,0) <>0

--and (l.price::decimal- COALESCE(p1.pay1::decimal,0) - COALESCE(p2.pay2::decimal,0) - COALESCE(p3.pay3::decimal,0)
-- -COALESCE(p4.pay4::decimal,0) - COALESCE(p5.pay5::decimal,0) - COALESCE(p6.pay6::decimal,0) ) <>0

order by name;''')

result = cursor.fetchall()
# for item in result:
#     print (it
col_names = []
for elt in cursor.description:
    col_names.append(elt[0])
df_crm_listings =pd.DataFrame(np.array(result), columns=col_names)
if (connection):
    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
df_crm_listings['status_changed_at_month'] = pd.to_datetime(df_crm_listings['status_changed_at'])
df_crm_listings['status_changed_at_month']= df_crm_listings['status_changed_at_month'].dt.strftime("%m-%y")
by_month=df_crm_listings[df_crm_listings['status_changed_at_month']=='03-21'] # вводить месяц
#by_month=df_crm_listings[df_crm_listings['status_changed_at_month']==lastMonth.strftime("%m-%Y")]
data_crm_listings = pd.pivot_table(by_month,index=['name'],values=['paid_amount'], aggfunc=np.sum)
# user_mail=['amit.das@latoken.com', 'egor.domakov@latoken.com', 'maksym.lenets@latoken.com','maxim.bisenov@latoken.com','maxine.gorbunova@latoken.com', 'malkov.nikita@latoken.com', 'sonny.mohanty@latoken.com', 'terrence.duncan@latoken.com']
# #data_crm_listings['email'] = user_mail
# listing_id=[]
# for j in data_crm_listings['email']:
#     for i in range(len(users_json)):
#             if j == users_json[i]['email']:
#                 listing_id.append(i)
# data_crm_listings['listing_user_id'] = listing_id
# data_crm_listings=data_crm_listings.reset_index()
# for value, mail, user_id  in zip( data_crm_listings['paid_amount'], data_crm_listings['email'], data_crm_listings['listing_user_id']):
#     data = {
#         "user": users_json[user_id], 
#        # "description": str(name),
#         "value": round(float(value),2),
#         "date": today,
#         "kpi_type": 31,
#         "unit": ['Listings'],
#     }
#     bearer_token = 'Bearer ' + token
#     headers = {'Authorization': bearer_token,
#                "Content-Type": "application/json"}
#     data = json.dumps(data)
#     url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
#     #r = requests.post(url, headers=headers, data=data)
# #   Revenue Listings, $   /////////////////////////////////////////////////////////////////////////
# data = {
    
#     "description": 'Revenue Listings, $',
#     "value": round(float(data_crm_listings['paid_amount'].sum()),2),
#     "date": today,
#     "kpi_type": 3,
#     "unit": ['Listings'],
# }
# bearer_token = 'Bearer ' + token
# headers = {'Authorization': bearer_token,
#            "Content-Type": "application/json"}
# data = json.dumps(data)
# url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
# #r = requests.post(url, headers=headers, data=data)
# Out:
# PostgreSQL connection is closed

# %%
#kpi  автоматизированно на 100% не использовать не правильные данные!

# %%
#	23	Revenue per Acc. manager - показатель по каждому Manager Customer Success Co-marketing

# %%
#///////////////////////////////////////////////////////////////////////////// 
#	23	Revenue per Acc. manager - показатель по каждому Manager Customer Success Co-marketing

register_adapter(dict, psycopg2.extras.Json) 
db_host = '135.181.61.116'
db_port = '5432'

connection = psycopg2.connect(dbname='postgres', user='crm_listings', 
                        password='', host='135.181.61.116', port = db_port)
cursor = connection.cursor()

cursor.execute('''with
     statuses_updates as (
         select *
         from (
                  select e.entity_id                                                                  as lead_id,
                         e.created_at                                                                 as update_dt,
                         (value_before[1] #>> '{lead_status,pipeline_id}')::bigint                        as before_status_pipeline_id,
                         (value_after[1] #>> '{lead_status,pipeline_id}')::bigint                         as after_status_pipeline_id,
                         (value_before[1] #>> '{lead_status,id}')::bigint                                 as before_status_id,
                         (value_after[1] #>> '{lead_status,id}')::bigint                                  as after_status_id
  --                       row_number() over (partition by e.entity_id order by created_at desc nulls last) as rn
                  from crm.event e
                  where e.type = 'lead_status_changed'
              ) w
--         where w.rn = 1
     )
select distinct (l.id) as lead_id,
l.name as project_name,
u.name,
l.closed_at,
l.status_id,
u.rights#>> '{role_id}' as role_id,
rc.responsible_updated::timestamp::date as responsible_changed,
       CASE WHEN st7.update_dt is not null THEN 'yes' ELSE 'no' END as services_produced,
sl.field_value::int as source_id
       --l.status_id as current_lead_status,
       --st1.before_status_id as status_prv,
       --st1.after_status_id as status_curr
from
     crm.lead l
     inner join crm.user u on (u.id = l.responsible_user_id)
     full outer join statuses_updates st7 on (l.id = st7.lead_id and st7.after_status_id=37660198)
     -- inner join 4288, left join 4900 == full outer join
left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as responsible_updated,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    --where e.type = 'entity_responsible_changed'
                    ) w
            where w.rn = 1) rc on (rc.lead_id=l.id)
left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as status_changed,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    --where e.type = 'lead_status_changed'
                    ) w
            where w.rn = 1) lsc on (lsc.lead_id=l.id)

left join (select l.id as lead_id,
   m.e #>> '{field_id}' as field_id,
   m.e #>> '{field_name}' as field_name,
   m.e #>> '{values,0,value}' as field_value
from crm.lead l,
lateral (select unnest(l.custom_fields_values ) e) m
where m.e#>>'{field_name}' = 'Source lead ID') sl on (sl.lead_id=l.id)

where
      -- e.entity_id = l.id
      --and e.type = ‘lead_status_changed’
      l.pipeline_id=3943576
      and u.id not in (1765393, 2777749,6679762,6039169,6462595,6405898,6387628) --‘Valentin Preobrazhenskiy’, ‘Leadgen’
      and l.is_deleted=false
      --and l.id=29960079
       --and l.name=‘PayPie (PPP)’

union all(
with
     statuses_updates as (
         select *
         from (
                  select e.entity_id                                                                  as lead_id,
                         e.created_at                                                                 as update_dt,
                         (value_before[1] #>> '{lead_status,pipeline_id}')::bigint                        as before_status_pipeline_id,
                         (value_after[1] #>> '{lead_status,pipeline_id}')::bigint                         as after_status_pipeline_id,
                         (value_before[1] #>> '{lead_status,id}')::bigint                                 as before_status_id,
                         (value_after[1] #>> '{lead_status,id}')::bigint                                  as after_status_id
  --                       row_number() over (partition by e.entity_id order by created_at desc nulls last) as rn
                  from crm.event e
                  where e.type = 'lead_status_changed'
                  order by e.created_at desc
              ) w
--         where w.rn = 1
     )
select distinct (l.id) as lead_id,
l.name as project_name,
u.name,
l.closed_at,
l.status_id,
u.rights#>> '{role_id}' as role_id,
rc.responsible_updated as responsible_changed,
'yes' as services_produced,
sl.field_value::int as source_id
       --l.status_id as current_lead_status,
       --st1.before_status_id as status_prv,
       --st1.after_status_id as status_curr

from
     crm.lead l
     inner join crm.user u on (u.id = l.responsible_user_id)
left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as responsible_updated,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    --where e.type = 'entity_responsible_changed'
                    ) w
            where w.rn = 1) rc on (rc.lead_id=l.id)
left join (select *
            from (select
                    e.entity_id as lead_id,
                    e.type,
                    e.created_at as status_changed,
                    e.value_before,
                    e.value_after,
                    row_number() over (partition by e.entity_id order by e.created_at desc nulls last) as rn
                    from crm.event e
                    --where e.type = 'lead_status_changed'
                    ) w
            where w.rn = 1) lsc on (lsc.lead_id=l.id)
     -- inner join 4288, left join 4900 == full outer join

left join (select l.id as lead_id,
   m.e #>> '{field_id}' as field_id,
   m.e #>> '{field_name}' as field_name,
   m.e #>> '{values,0,value}' as field_value
from crm.lead l,
lateral (select unnest(l.custom_fields_values ) e) m
where m.e#>>'{field_name}' = 'Source lead ID') sl on (sl.lead_id=l.id)

where
      -- e.entity_id = l.id
      --and e.type = ‘lead_status_changed’
      l.pipeline_id=3963949
      and u.id not in (1765393, 2777749,6679762,6039169,6405898,6462595,6211156,6387628)
      and l.is_deleted=false
    )
order by project_name desc;''')

result = cursor.fetchall()
# for item in result:
#     print (item)
col_names = []
for elt in cursor.description:
    col_names.append(elt[0])
df_cs =pd.DataFrame(np.array(result), columns=col_names)
if (connection):
    cursor.close()
    connection.close()
    print("PostgreSQL connection is closed")
joined_data=pd.merge(df_crm_listings,df_cs,left_on='lead_id',right_on='source_id',how='left')

lists_of_cs_user = ['alexandra.smirnova@latoken.com','dmitry.dubkov@latoken.com','pavel.pilikin@latoken.com','richa.patil@latoken.com','sekai.sungani@latoken.com']
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
user_dic_cs = {}
for mail in lists_of_cs_user:
    mail_changed = mail.replace('@latoken.com', '').lower()
    for name in df_cs['name']:
        name_changed = name.lower()
        if (similar(mail_changed, name_changed)>0.8):
            #print(similar(mail_changed,name_changed))
            user_dic_cs[name] = mail
names_mails_cs=pd.DataFrame.from_dict(user_dic_cs,orient='index',columns=[ 'mail']).reset_index()
joined_data=joined_data[joined_data['status_changed_at_month']=='03-21']# поставить условие за прошлый месяц format %m%Y
df_pivot = joined_data.groupby(["project_name_x","name_y"])['paid_amount'].sum().reset_index()
df_pivot = df_pivot[df_pivot.paid_amount != 0]
kpi_X=(df_pivot['paid_amount'].sum()) / (df_pivot['project_name_x'].count())
count_projects=df_pivot.groupby(["name_y"])['project_name_x'].count().to_frame().reset_index()
lists_of_kpi = []
for name, count in zip(count_projects['name_y'], count_projects['project_name_x']):
    lists_of_kpi.append(kpi_X * count)
count_projects['values']=lists_of_kpi
finished_df_kpi=count_projects.merge(names_mails_cs, left_on='name_y', right_on='index')

cs_id=[]
for j in finished_df_kpi['mail']:
    for i in range(len(users_json)):
            if j == users_json[i]['email']:
                cs_id.append(i)
finished_df_kpi['cs_user_id'] = cs_id
#data_crm_listings=data_crm_listings.reset_index()

# for value, user_id  in zip( finished_df_kpi['values'], finished_df_kpi['cs_user_id']):
#     data = {
#         "user": users_json[user_id], 
#        # "description": str(name),
#         "value": round(float(value),2),
#         "date": today,
#         "kpi_type": 23,
#         "unit": ['Customer Success'],
#     }
#     bearer_token = 'Bearer ' + token
#     headers = {'Authorization': bearer_token,
#                "Content-Type": "application/json"}
#     data = json.dumps(data)
#     url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
#     r = requests.post(url, headers=headers, data=data)
# Out:
# PostgreSQL connection is closed

# %%
# d=joined_data.groupby("name_x")["token_name"]
# d.head(10)
# Out:
# 0        RLE
# 1      WIDER
# 2      (GLT)
# 3        BHF
# 4        HVE
# 7       RDEE
# 8      AGOLP
# 9        SVX
# 10       GCG
# 13       TKG
# 21       SFM
# 22       CBT
# 24         -
# 25     ERSDL
# 32       E3E
# 38       DIE
# 39      ORBS
# 42    ELCash
# Name: token_name, dtype: object

# %%
#//////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
#Traders_aquired from coda  проверить если нет дублирующих строк!, kpi  автоматизированно на 100% 
# Autorization Coda
coda_token = '9175cdcc-32f3-469b-abfe-680914bad093' # Coda token
headers = {'Authorization': f'Bearer {coda_token}'}
url = f'https://coda.io/apis/v1/docs/tOejP8k2Xp/tables/grid-oB7P1MNta6/rows'
req = requests.get(url, headers=headers)
req.raise_for_status() # Throw if there was an error.
res = req.json()
list = res['items']
length = len(list)
month = []
value = []
for i in range(length):
    month.append(res['items'][i]['values']['c-wJjfHcGtiD'])
    value.append(res['items'][i]['values']['c-7br5JmBaE8'])
df = pd.DataFrame(month, columns = ['month'])
df['value'] = value
df['month']= pd.to_datetime(df['month'], format='%Y%m', errors='ignore')
import datetime
from dateutil.relativedelta import *
import datetime
todays_month = datetime.date.today()
first = todays_month.replace(day=1)
coda_day = first - datetime.timedelta(days=1)
print(coda_day.strftime("%Y-%m"))
#coda_day = datetime.date.today()  # data for now format Y/M 2021-02
#coda_day = "2021-03"
previos_3_months = (datetime.datetime.now() - relativedelta(months=3)).strftime("%Y-%m") # previos thre months format Y/M 2021-01
average = []
if (df['month'].iloc[0] == coda_day.strftime("%Y-%m")):
    for date, val  in zip(df['month'], df['value']):
        if (date == coda_day.strftime("%Y-%m")):
            today_month_value= val
        if (date >= previos_3_months) & (date != coda_day.strftime("%Y-%m")):
            average.append(val)
            #print(date)
today_month_value = 20807
delta=today_month_value-round(mean(average),3) 
Traders_aquired=round(delta/round(mean(average),3),2)
data = {
   # "user": users_json[user_id],
    "description": '% Traders aquired',
    "value": Traders_aquired,
    "date": today,
    "kpi_type": 40,#% Traders aquired
    "unit": ["Growth"]
}
headers = {'Authorization': 'Bearer ' + token,
           "Content-Type": "application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
r.json()
# Out:
# 2021-03
# {'id': 274,
#  'user': None,
#  'description': '% Traders aquired',
#  'value': 1.99,
#  'date': '31/03/2021',
#  'kpi_type': 40,
#  'unit': ['Growth']}

# %%
#kpi  автоматизированно на 100% 
#total revenue сумма (Revenue Listings, $ + Revenue Pitches, $ + Revenue LS (service fees), $ + LS trading fees, $+ Revenue Trading fees (non-LS), $ + Revenue D/W fees, $)
header = {'Authorization': bearer_token}
url = 'http://new.la-team.tk/api/kpi-coefficient-values/?start_date=2021-02-01&end_date=2021-02-28'
req = requests.get(url, headers=header)
response = req.json()
total_revenue={"Revenue Listings  $" : 3,  "Revenue Pitches, $" :4 , "Revenue LS (service fees), $" : 5 ,  "LS trading fees, $":6, "Revenue Trading fees (non-LS), $" : 7, "Revenue D/W fees, $":8}
total_revenue_kpi = []
for j in range(len(response)):
    for kpi in total_revenue:
        if (response[j]['kpi_type']== total_revenue[kpi]):
            total_revenue_kpi.append(response[j]['value'])

data = {
        "description": 'Revenue Listings, $ + Revenue Pitches, $ + Revenue LS (service fees), $ + LS trading fees, $+ Revenue Trading fees (non-LS), $ + Revenue D/W fees, $',
        "value": sum(total_revenue), #value export to platform
        "date": today,# todays day
        "kpi_type":  53 # 2,#53	Revenue Listings, $ + Revenue Pitches, $+ Revenue LS (service fees), $+ LS trading fees, $

    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://ops-frontend.dev3.nekotal.tech/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4ef22a045a0f> in <module>
#       1 #total revenue сумма (Revenue Listings, $ + Revenue Pitches, $ + Revenue LS (service fees), $ + LS trading fees, $+ Revenue Trading fees (non-LS), $ + Revenue D/W fees, $)
# ----> 2 header = {'Authorization': bearer_token}
#       3 url = 'http://new.la-team.tk/api/kpi-coefficient-values/?start_date=2021-02-01&end_date=2021-02-28'
#       4 req = requests.get(url, headers=header)
#       5 response = req.json()
#
# NameError: name 'bearer_token' is not defined

# %%
#next_kpi values

# %%
# кол-во новых трейдеров, которые привлекли по своим каналам CS и Growth менеджеры, kpi  автоматизированно на 100%
register_adapter(dict, psycopg2.extras.Json) 
db_host = '135.181.61.116'
db_port = '5432'
db_database = 'postgres'
db_user = 'edyu'
db_password = 'UatxSWygbeby62SHshHYm'

connection = psycopg2.connect(dbname='postgres', user='edyu', 
                        password='UatxSWygbeby62SHshHYm', host='135.181.61.116', port = db_port)
cursor = connection.cursor()

##sql = "select distinct task #>> '{unit}' as unit, (case when is_critical = true then count(is_critical) end) as count from platform.checklist
##group by checklist.task, checklist.is_critical %s" % tablename
cursor.execute("select manager_name, non_organic_new_traders_acquired from traders_by_managers_daily;")

result = cursor.fetchall()

for item in result:
    print (item)
df =pd.DataFrame(np.array(result))
df.rename(columns={0:'name', 1:'value'}, inplace=True)
#//////если выдает тут ошибку проверит список возможно нет user mail
list_of_traders=['alexandra.smirnova@latoken.com','tessa.popil@latoken.com','julius.mitkevich@latoken.com','sekai.sungani@latoken.com', 'dmitry.dubkov@latoken.com', 'aleksandra.grebenshchikova@latoken.com','bertram.cameron@latoken.com','andrey.fedotov@latoken.com', 'richa.patil@latoken.com', 'alexandra.smirnova@latoken.com', 'pavel.pilikin@latoken.com']
#//////////////////////////////////////////////////////////////////////
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
#///////////////////////////////////////////////////////////////////////////////////////////////////
user_traders_cs = {}
for mail in list_of_traders:
    mail_changed = mail.replace('@latoken.com', '').lower()
    for name in df['name']:
        name_changed = name.lower()
        if (similar(mail_changed, name_changed)>0.8):
            #print(similar(mail_changed,name_changed))
            user_traders_cs[name] = mail
names_traders=pd.DataFrame.from_dict(user_traders_cs,orient='index',columns=[ 'mail']).reset_index()
finished_df_kpi=df.merge(names_traders, left_on='name', right_on='index')
traders_id=[]
for j in finished_df_kpi['mail']:
    for i in range(len(users_json)):
            if j == users_json[i]['email']:
                traders_id.append(i)
finished_df_kpi['traders_user_id'] = traders_id

unit = []
for i in finished_df_kpi['traders_user_id']:
    unit.append(users_json[i]['unit'][0]['unit'])
finished_df_kpi['unit'] = unit

for name, value, user_id, unit in zip(finished_df_kpi['name'], finished_df_kpi['value'], finished_df_kpi['traders_user_id'], finished_df_kpi['unit']):
    data = {
        "user": users_json[user_id],
        "description": name,
        "value": round(float(value),2),
        "date": today,
        "kpi_type": 46, #46	кол-во новых трейдеров, которые привлекли по своим каналам CS и Growth менеджеры
        "unit": [unit],
    }
    bearer_token = 'Bearer ' + token
    headers = {'Authorization': bearer_token,
               "Content-Type": "application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())
cursor.close()
connection.close()
# unit из user_json добавить unit
# Out:
# ('Julius Mitkevich', 0.0)
# ('Tessa Popil', 0.0)
# ('Sekai Sungani', 177.25)
# ('Dmitry Dubkov', 2432.0833333333335)
# ('Alexandra Grebenschikova', 526.0)
# ('Bertram Cameron', 368.5)
# ('Andy Fedotov', 385.0)
# ('Richa Patil', 6743.5)
# ('Alexandra Smirnova', 6123.75)
# ('Pavel Pilikin', 1301.0833333333335)
# ...

# %%
#////////////////////////////////////////////////////Отзывы Android

# %%
# Отзывы Android,  автоматизированно на 100%
gc = pygsheets.authorize(service_file='Pitching-9f5ef2fa7cdc.json')
#open the google spreadsheet (where 'PY to Gsheet Test' is the name of my sheet)
sh = gc.open('Mobile Customers Satisfaction')
#select the first sheet 
wks = sh[4]
df = wks.get_as_df()
df.columns = ['date_start','date_end','start', 'end','Agent','WAvg','WAvgBonus','12,5','34,5','123,4','12,3','HM bonu','Total bonus']
cols_to_check = ['WAvg', 'WAvgBonus', '12,5', '34,5', '123,4',
       '12,3', 'HM bonu', 'Total bonus']
df[cols_to_check] = df[cols_to_check].replace({'₽':''}, regex=True).replace({',':''}, regex=True)
df['date_start']= pd.to_datetime(df['date_start'])
df['date_end']= pd.to_datetime(df['date_end'])
df['month_of_start'] = df['date_start'].dt.month
df['month_of_end'] = df['date_end'].dt.month
data_denis_dvoryankin=df[df['Agent']=='Denis Dvoryankin']
data_Ihor_Ponomarenko=df[df['Agent']=='Ihor Ponomarenko']
data_denis_dvoryankin['WAvg'] = pd.to_numeric(data_denis_dvoryankin['WAvg'])
data_Ihor_Ponomarenko['WAvg'] = pd.to_numeric(data_Ihor_Ponomarenko['WAvg'])
data_denis_dvoryankin=data_denis_dvoryankin.loc[data_denis_dvoryankin['WAvg'].isnull()!=True]
data_Ihor_Ponomarenko=data_Ihor_Ponomarenko.loc[data_Ihor_Ponomarenko['WAvg'].isnull()!=True]
dvoryankin=data_denis_dvoryankin[(data_denis_dvoryankin['month_of_end']>2) & (data_denis_dvoryankin['month_of_start']<4)]# за нужный месяц прописываем больше прошлого но меньше предыдущего
dvoryankin=dvoryankin[['WAvg','12,5','34,5','123,4','12,3']]
ponomarenko=data_Ihor_Ponomarenko[(data_Ihor_Ponomarenko['month_of_end']>2) & (data_Ihor_Ponomarenko['month_of_start']<4)] # за нужный месяц прописываем больше прошлого но меньше предыдущего
ponomarenko=ponomarenko[['WAvg','12,5','34,5','123,4','12,3']]
column = ['WAvg', '12,5', '34,5', '123,4', '12,3']
Dict_kpi = {'Отзывы Android, изменённые с 3, 4 → 5 [4 week]':66,'Отзывы Android, изменённые с 3, 4 → 5 [3 week]':65,'Отзывы Android, изменённые с 3, 4 → 5 [2 week]':64,'Отзывы Android, изменённые с 3, 4 → 5 [1 week]':35,
            'Отзывы Android, изменённые с 1, 2 → 5 [4 week]':63,'Отзывы Android, изменённые с 1, 2 → 5 [3 week]':62,'Отзывы Android, изменённые с 1, 2 → 5 [2 week]':61,'Отзывы Android, изменённые с 1, 2 → 5 [1 week]':34,
            'Отзывы Android, изменённые с 1, 2, → 3 [4 week]':57,'Отзывы Android, изменённые с 1, 2, 3 → 4 [4 week]':60,'Отзывы Android, изменённые с 1, 2, 3 → 4 [3 week]':59,'Отзывы Android, изменённые с 1, 2, 3 → 4 [2 week]':58,
            'Отзывы Android, изменённые с 1, 2, → 3 [2 week]':55,'Weekly average mobile rating [4 week]':69,
            'Weekly average mobile rating [3 week]':68,'Weekly average mobile rating [1 week]':33,
            'Weekly average mobile rating [2 week]':67,'Отзывы Android, изменённые с 1, 2, → 3 [3 week]':56,
            'Отзывы Android, изменённые с 1, 2, 3 → 4 [1 week]': 48,
              'Отзывы Android, изменённые с 1, 2, → 3 [1 week]': 47}
#define weeks
weeks = []
rows = len(ponomarenko)+1
for i in range(1,rows):
    weeks.append('[{} week]'.format(i))
ponomarenko['weeks']=weeks
    
for j in range(len(users_json)):
    if (users_json[j]['email']== 'denis.dvoryankin@latoken.com'):
        denis_dvoryankin_id = j
for j in range(len(users_json)):
    if (users_json[j]['email']== 'ihor.ponomarenko@latoken.com'):
        ponomarenkon_id = j
# export to platform      
weeks = []
rows = len(dvoryankin)+1
for i in range(1,rows):
    weeks.append('[{} week]'.format(i))
dvoryankin['weeks']=weeks
#kpi mobile for denis.dvoryankin@latoken.com
kpi = []
dictionary = {'kpi_id':[], 'kpi_type':[], 'index_df':[]}
for word, index, (colname, columdata) in zip(dvoryankin['weeks'], dvoryankin.index, dvoryankin.iteritems() ):
    for key, kpi_id in Dict_kpi.items():
        if word in key:
            kpi.append(kpi_id)
            print(kpi_id, key, index, colname)
            dictionary["kpi_id"].append(kpi_id)
            dictionary["kpi_type"].append(key)
            dictionary["index_df"].append(index)
            #dictionary["colum_df"].append(colname)
Kpi_df = pd.DataFrame(dictionary)

def export_kpi_platform(kpi_id, value):
    data = {
        "user": users_json[denis_dvoryankin_id], # denis.dvoryankin@latoken.com	
       # "description": name,
        "value": value,
        "date": today,
        "kpi_type": kpi_id, 
        "unit": ['Mobile'],
    }
    bearer_token = 'Bearer ' + token
    headers = {'Authorization': bearer_token,
               "Content-Type": "application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())
#//////
def mobile_kpi(column, kpi):
    res = []
    lengh = len(dvoryankin[column]) + 1
    for val, u in zip(range(1,lengh),dvoryankin[column]) :
   # for it in range(1,5):
        for i, kpi_id in zip(Kpi_df['kpi_type'],Kpi_df['kpi_id']) :
            if (i==kpi.format(val)):
            #Kpi_df['colum_df'] = u
                print(i)
                print(u)
                print(kpi_id)
                export_kpi_platform( kpi_id ,u)

mobile_kpi('WAvg', 'Weekly average mobile rating [{} week]')
mobile_kpi('12,5', 'Отзывы Android, изменённые с 1, 2 → 5 [{} week]')
mobile_kpi('34,5', 'Отзывы Android, изменённые с 3, 4 → 5 [{} week]')
mobile_kpi('123,4', 'Отзывы Android, изменённые с 1, 2, 3 → 4 [{} week]')
mobile_kpi('12,3', 'Отзывы Android, изменённые с 1, 2, → 3 [{} week]')
#////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# #kpi mobile for ihor.ponomarenko@latoken.com
kpi = []
dictionary = {'kpi_id':[], 'kpi_type':[], 'index_df':[]}
for word, index, (colname, columdata) in zip(ponomarenko['weeks'], ponomarenko.index, ponomarenko.iteritems() ):
    for key, kpi_id in Dict_kpi.items():
        if word in key:
            kpi.append(kpi_id)
            print(kpi_id, key, index, colname)
            dictionary["kpi_id"].append(kpi_id)
            dictionary["kpi_type"].append(key)
            dictionary["index_df"].append(index)
            #dictionary["colum_df"].append(colname)
Kpi_df = pd.DataFrame(dictionary)

def export_kpi_platform(kpi_id, value):
    data = {
        "user": users_json[ponomarenkon_id], # denis.dvoryankin@latoken.com	
       # "description": name,
        "value": value,
        "date": today,
        "kpi_type": kpi_id, 
        "unit": ['Mobile'],
    }
    bearer_token = 'Bearer ' + token
    headers = {'Authorization': bearer_token,
               "Content-Type": "application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())
# #///////////////////////////////////////////////////////////////////////
def mobile_kpi(column, kpi):
    res = []
    lengh = len(ponomarenko[column]) + 1
    for val, u in zip(range(1,lengh),ponomarenko[column]) :
   # for it in range(1,5):
        for i, kpi_id in zip(Kpi_df['kpi_type'],Kpi_df['kpi_id']) :
            if (i==kpi.format(val)):
            #Kpi_df['colum_df'] = u
                print(i)
                print(u)
                print(kpi_id)
                export_kpi_platform( kpi_id ,u)

mobile_kpi('WAvg', 'Weekly average mobile rating [{} week]')
mobile_kpi('12,5', 'Отзывы Android, изменённые с 1, 2 → 5 [{} week]')
mobile_kpi('34,5', 'Отзывы Android, изменённые с 3, 4 → 5 [{} week]')
mobile_kpi('123,4', 'Отзывы Android, изменённые с 1, 2, 3 → 4 [{} week]')
mobile_kpi('12,3', 'Отзывы Android, изменённые с 1, 2, → 3 [{} week]')
# Out:
# <ipython-input-275-52bc4ddf21af>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_denis_dvoryankin['WAvg'] = pd.to_numeric(data_denis_dvoryankin['WAvg'])
# <ipython-input-275-52bc4ddf21af>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_Ihor_Ponomarenko['WAvg'] = pd.to_numeric(data_Ihor_Ponomarenko['WAvg'])
# 35 Отзывы Android, изменённые с 3, 4 → 5 [1 week] 10 WAvg
# 34 Отзывы Android, изменённые с 1, 2 → 5 [1 week] 10 WAvg
# 33 Weekly average mobile rating [1 week] 10 WAvg
# ...

# %%
#next kpi values

# %%
# trustpilot rating and revain  автоматизированно на 100%
revain = requests.get('https://revain.org/exchanges/latoken')
revain = BeautifulSoup(revain.text, 'html.parser')
trustpilot = requests.get('https://www.trustpilot.com/review/www.latoken.com')
trustpilot = BeautifulSoup(trustpilot.text, 'html.parser')
trustpilot_tags=trustpilot.find_all('script')
revain_tags=revain.find_all('script')
trustpilot_score=trustpilot_tags[18]
revain_score=revain_tags[1]
revain_score = str(revain_score)
trustpilot_score= str(trustpilot_score)

revain_score=re.sub('<[^>]*>', '', revain_score) 
trustpilot_score=re.sub('<[^>]*>', '', trustpilot_score) 
revain_score = json.loads(revain_score) 
trustpilot_score = json.loads(trustpilot_score)
trustpilot_score=trustpilot_score['trustScore']
revain_score=revain_score['aggregateRating']['ratingValue']
# revain_score  esther.babatunde@latoken.com
for j in range(len(users_json)):
    if (users_json[j]['email']== 'esther.babatunde@latoken.com'):
        usq_id = j

data = {
        "user":users_json[usq_id] ,#esther.babatunde@latoken.com
        "description": 'Revain.org rating',
        "value": revain_score,
        "date": today,
        "kpi_type": 25,#Revain.org rating
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
#///////////////////////////////////////////////////////////////////
for j in range(len(users_json)):
    if (users_json[j]['email']== 'errol.shabani@latoken.com'):
        use_id = j
data = {
        "user":users_json[use_id] ,# errol.shabani@latoken.com
        "description": 'Trustpilot rating',
        "value": trustpilot_score,
        "date": today,
        "kpi_type": 24,#Trustpilot rating
        "unit": ["Customer Success"]
    }
# bearer_token = 'Bearer '+ token
# headers = {'Authorization': bearer_token,
#               "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 272, 'user': {'id': 40, 'email': 'errol.shabani@latoken.com', 'full_name': 'Shabani Errol', 'role': [{'role': 'Senior Manager Customer Success Satisfaction', 'id': 138, 'status': 'In operation', 'problem_to_solve': 'Increase the speed of tickets being resolved by utilizing automations.', 'requirement_skills_and_experience': 'English CR1, customer support experience, trading crypto experience, desire to grow as a specialist, sales experience, olympiad winner, fintech', 'keywords': 'Crypto, B2B sales, fintech, account management, zendesk', 'additional_comment': '', 'vacancy_link': '', 'ideal_cv': '', 'manager_hiring': 157, 'hrbp': 155, 'main_performance_number': 'Ticket satisfaction rate', 'second_performance_number': '', 'third_performance_number': ''}], 'unit': [{'unit': 'Customer Success', 'role': [{'role': 'Business Analyst Trainee', 'id': 73, 'status': 'In operation', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment'
# ...

# %%
#% времени нарушения целей по спредам,  автоматизированно на 99%, нужно обновлять token, срок истекает 1 день
token_terminal = 'C8a6pantU7KbGy_TTHhUELijeMkeaZD0z1ISIMNxT9Q' # нужно обновлать token find {application -> local storage->http...-> token}
headers_terminal = {'Terminal-Auth':token_terminal,'longSession':'True'}
beginning = datetime.datetime(2021, 3, 1)#начало месяца вводить
end = datetime.datetime(2021, 3, 31) # конец месяца
ss_300_week = requests.get(f'https://terminal.nekotal.tech/api/co/TradingMetrics/get-spread-success?target=3&spreadTarget=35&from={beginning}&to={end}', headers = headers_terminal).json()
ss_30_week = requests.get(f'https://terminal.nekotal.tech/api/co/TradingMetrics/get-spread-success?target=2&spreadTarget=7&from={beginning}&to={end}', headers = headers_terminal).json()
ss_300_list_week = []
for i in range(len(ss_300_week)):
    ss_300_list_week.append(ss_300_week[i]['percentage'])
for i in range(len(ss_30_week)):
    ss_300_list_week.append(ss_30_week[i]['percentage'])
inputs = str("{:.1f}".format(np.mean(ss_300_list_week)))
#print(inputs)
#///////////////////////////////////////////////////////////////
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='% времени нарушения целей по спредам'):
        get_spread_success_id = kpi_json[j]['id']
for j in range(len(users_json)):
    if (users_json[j]['email']== 'stanislav.novikov@latoken.com'):
        us_id = j
data = {
        "user":users_json[us_id] ,#roman.belevskiy@latoken.com
        "description": 'по топ 2 - 2bps, по топ 30 - 7bps, по топ 300 - 35 bps таргеты. Соответственно при достижении 95% (от общего времени) считается что таргет достигнут. Данная цифра показывает  среднее время вне таргетов, то есть нарушено заявленное значение.',
        "value": (100 - float(inputs))/100,
        "date": today,
        "kpi_type": 43,# % времени нарушения целей по спредам
        "unit": ["Trading Desk"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 336, 'user': {'id': 276, 'email': 'stanislav.novikov@latoken.com', 'full_name': 'Novikov Stanislav', 'role': [{'role': 'Director Trading Desk Traders Growth and Risk', 'id': 132, 'status': 'In operation', 'problem_to_solve': '', 'requirement_skills_and_experience': '', 'keywords': '', 'additional_comment': '', 'vacancy_link': '', 'ideal_cv': '', 'manager_hiring': 31, 'hrbp': 184, 'main_performance_number': '1', 'second_performance_number': '', 'third_performance_number': ''}], 'unit': [{'unit': 'Trading Desk', 'role': [{'role': 'Trainee Trading Desk Liquidity', 'id': 329, 'status': 'Archive', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment': None, 'vacancy_link': None, 'ideal_cv': None, 'manager_hiring': None, 'hrbp': None, 'main_performance_number': None, 'second_performance_number': None, 'third_performance_number': None}, {'role': 'Team Lead Trading Desk Traders, Traders Growth and Risk', 'id': 344, 'status': 'Archi
# ...

# %%
#next kpi value/////////////////////////////////////

# %%
# Withdrawal_Success_Rate_2H coda /// 12	D/W success rate  автоматизированно на 100%
#now = datetime.now() # current date and time
# Autorization Coda
coda_token = '9175cdcc-32f3-469b-abfe-680914bad093' # Coda token
headers = {'Authorization': f'Bearer {coda_token}'}
#headers = {'Authorization': 'Bearer <your token id>'}#insert your token id instead of 
url = f'https://coda.io/apis/v1/docs/iCAmiFZp3V/tables/grid-WRXRPvlKGg/rows'

req = requests.get(url, headers=headers)
req.raise_for_status() # Throw if there was an error.
res = req.json()
list = res['items']
length = len(list)
rows = []
for i in range(length):
    #print(list[i])
    if (res['items'][i]['values']['c-CngO3nBVwd']=='PAYMENTS') == True:
        rows.append(i)
Withdrawal_Success_Rate_2H = res['items'][rows[0]]['values']['c-frtwdv0LLO']
#////////////////////////
# Withdrawal success rate (2h)- общий'):
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='Withdrawal success rate (2h)'):
        Withdrawal_success_rate = kpi_json[j]['id']
data = {
        "description": '12	D/W success rate',
        "value": round(Withdrawal_Success_Rate_2H/100.0, 2),
        "date": today,
        "kpi_type": 12,#D/W success rate

    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 273, 'user': None, 'description': '12\tD/W success rate', 'value': 0.96, 'date': '31/03/2021', 'kpi_type': 12, 'unit': []}

# %%
'''Zendesk -> 4 квадратика в левом верхнем углу -> Chat->Analytics-> Agent report-> выбираем дату с 1-го по последний день месяца
#и берем поля:
  Agent
Email
Satisfaction (показатель Chat Satisfaction rate per acc manager)
Response time (показатель First response time per acc manager)'''

# %%
#///////////////////////////////////////////////////////////// zendesc First_response_time

# %%
all_data_from_zendesk=pd.read_csv('department_agents_chats_.csv')
pd.pivot_table(all_data_from_zendesk,index=["Email","Name"],values=["Minimum of First Response Time (sec)"],aggfunc = np.mean)
agent_satisfaction=pd.pivot_table(all_data_from_zendesk,index=["Email","Name"],values=["Bad","Good"],aggfunc = np.sum)
sum_column = agent_satisfaction["Bad"] + agent_satisfaction["Good"]
agent_satisfaction["sum"] = sum_column

satifacotin_rate = ((agent_satisfaction["Good"]*100)/agent_satisfaction["sum"])/100
agent_satisfaction["satifacotin_rate"] = satifacotin_rate
agent_satisfaction=agent_satisfaction.reset_index()
agent_satisfaction=agent_satisfaction[agent_satisfaction.Email != 'assistant@latoken.com']
#agent_satisfaction=agent_satisfaction.drop(['assistant@latoken.com'])
agent_satisfaction['email'] = agent_satisfaction['Email']
# Out:
# Index(['Department Name', 'Name', 'Email', 'Enabled', 'Start Time (GMT+0)',
#        'End Time (GMT+0)', 'Completed Chats', 'Dropped Chats', 'Missed Chats',
#        'Acceptance', 'Assigned Chats', 'Accepted Chats', 'Visitor Initiated',
#        'Agent Initiated', 'Trigger Initiated', 'Visitor Initiated (Completed)',
#        'Agent Initiated (Completed)', 'Trigger Initiated (Completed)',
#        'Visitor Initiated (Dropped)', 'Agent Initiated (Dropped)',
#        'Trigger Initiated (Dropped)', 'Visitor Initiated (Missed)',
#        'Agent Initiated (Missed)', 'Trigger Initiated (Missed)',
#        'Unresponsive Chats', 'Agent Initiated (Unresponsive)',
#        'Trigger Initiated (Unresponsive)', 'Chat Satisfaction', 'Chats Rated',
#        'Good', 'Bad', 'Average of First Response Time (sec)',
#        'Maximum of First Response Time (sec)',
#        'Minimum of First Response Time (sec)', 'Average Chat Duration (sec)',
# ...

# %%
First_response_time = [] # вводить вручную показатели first response time!,  автоматизированно на 30%, нет доступа к api платное
for email in agent_satisfaction['email']:
    print(email)
    score = input('input score :' )
    score = (60  / (float(score)*60))
    print(email) 
#     score = input('input score :' )
    First_response_time.append(score) #agent_satisfaction.append({'Bad': score} ,ignore_index=False) 
#    #agent_satisfaction["First_response_time_2"] = First_response_time
agent_satisfaction['First_response_time'] = First_response_time
First_response_time_for_all  = statistics.mean(First_response_time)
# Out:
# benita.nmeholam@latoken.com
# input score :18.59
# benita.nmeholam@latoken.com
# daniel.ademiluka@latoken.com
# input score :17.29
# daniel.ademiluka@latoken.com
# ekaterina.sukhinina@latoken.com
# input score :7.39
# ekaterina.sukhinina@latoken.com
# errol.shabani@latoken.com
# input score :14.44
# errol.shabani@latoken.com
# esther.babatunde@latoken.com
# input score :8.21
# esther.babatunde@latoken.com
# john.babatunde@latoken.com
# input score :3.9
# john.babatunde@latoken.com
# kush.amonzoda@latoken.com
# input score :7.18
# kush.amonzoda@latoken.com
# samuel.bankole@latoken.com
# input score :9.1
# samuel.bankole@latoken.com
# sekai.sungani@latoken.com
# input score :1.23
# sekai.sungani@latoken.com

# %%
#total_First_response_time - общий'):
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='First response time <60 sec (remote supp.) - общий'):
        first_response_time_id = kpi_json[j]['id']
First_response_time_for_all  = round(statistics.mean(First_response_time), 2) 
data = {
        "description": 'First response time <60 sec (remote supp.) - общий',
        "value": First_response_time_for_all,
        "date": today,
        "kpi_type": 16,#First response time <60 sec (remote supp.) - общий
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 286, 'user': None, 'description': 'First response time <60 sec (remote supp.) - общий', 'value': 0.2, 'date': '31/03/2021', 'kpi_type': 16, 'unit': ['Customer Success']}

# %%
#total_First_response_time - общий' dovzhenko.alexander@latoken.com ):
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='First response time <60 sec (remote supp.) - общий'):
        first_response_time_id = kpi_json[j]['id']
First_response_time_for_all  = round(statistics.mean(First_response_time), 2) 
for j in range(len(users_json)):
    if (users_json[j]['email']== 'dovzhenko.alexander@latoken.com'):# check if he is base его нет в базе
        dovzhenko_id = j
data = {
        "user":users_json[dovzhenko_id],
        "description": 'First response time <60 sec (remote supp.) - общий',
        "value": First_response_time_for_all,
        "date": today,
        "kpi_type": 16,#First response time <60 sec (remote supp.) - общий
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 287, 'user': {'id': 157, 'email': 'dovzhenko.alexander@latoken.com', 'full_name': 'Dovzhenko Alexander', 'role': [{'role': 'Director Customer Success Rate', 'id': 114, 'status': 'In operation', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment': None, 'vacancy_link': None, 'ideal_cv': None, 'manager_hiring': None, 'hrbp': None, 'main_performance_number': None, 'second_performance_number': None, 'third_performance_number': None}], 'unit': [{'unit': 'Customer Success', 'role': [{'role': 'Business Analyst Trainee', 'id': 73, 'status': 'In operation', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment': None, 'vacancy_link': None, 'ideal_cv': None, 'manager_hiring': None, 'hrbp': None, 'main_performance_number': None, 'second_performance_number': None, 'third_performance_number': None}, {'role': 'Director Customer Success Rate', 'id': 114, 'status': 'In operation', 'pro
# ...

# %%
#total_chat_satisfaction_rate
# Chat satisfaction rate - общий'):
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='Chat satisfaction rate - общий'):
        total_chat_satisfaction_id = kpi_json[j]['id']
total_chat_satisfaction_rate=round((agent_satisfaction['Good'].sum()*100)/(agent_satisfaction['Good'].sum() + agent_satisfaction['Bad'].sum())/100, 2)
data = {
        "description": 'Chat satisfaction rate - общий',
        "value": total_chat_satisfaction_rate,
        "date": today,
        "kpi_type": total_chat_satisfaction_id,
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 288, 'user': None, 'description': 'Chat satisfaction rate - общий', 'value': 0.79, 'date': '31/03/2021', 'kpi_type': 14, 'unit': ['Customer Success']}

# %%
#total_chat_satisfaction_rate by dovzhenko.alexander@latoken.com
# Chat satisfaction rate - общий'):
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='Chat satisfaction rate - общий'):
        total_chat_satisfaction_id = kpi_json[j]['id']
total_chat_satisfaction_rate=round((agent_satisfaction['Good'].sum()*100)/(agent_satisfaction['Good'].sum() + agent_satisfaction['Bad'].sum())/100, 2)
for j in range(len(users_json)):
    if (users_json[j]['email']== 'dovzhenko.alexander@latoken.com'):# его нет в базе
        dovzhenko_id = j
data = {
        "user":users_json[dovzhenko_id],
        "description": 'Chat satisfaction rate - общий',
        "value": total_chat_satisfaction_rate,
        "date": today,
        "kpi_type": total_chat_satisfaction_id,
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
r = requests.post(url, headers=headers, data=data)
print(r.json())
# Out:
# {'id': 289, 'user': {'id': 157, 'email': 'dovzhenko.alexander@latoken.com', 'full_name': 'Dovzhenko Alexander', 'role': [{'role': 'Director Customer Success Rate', 'id': 114, 'status': 'In operation', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment': None, 'vacancy_link': None, 'ideal_cv': None, 'manager_hiring': None, 'hrbp': None, 'main_performance_number': None, 'second_performance_number': None, 'third_performance_number': None}], 'unit': [{'unit': 'Customer Success', 'role': [{'role': 'Business Analyst Trainee', 'id': 73, 'status': 'In operation', 'problem_to_solve': None, 'requirement_skills_and_experience': None, 'keywords': None, 'additional_comment': None, 'vacancy_link': None, 'ideal_cv': None, 'manager_hiring': None, 'hrbp': None, 'main_performance_number': None, 'second_performance_number': None, 'third_performance_number': None}, {'role': 'Director Customer Success Rate', 'id': 114, 'status': 'In operation', 'pro
# ...

# %%
# next kpi values #'Chat satisfaction rate - по каждому менеджеру CS'):

# %%
merged_left = pd.merge(left=agent_satisfaction, right=users, how='left', left_on='email', right_on='email')
data_chat_satisfaction_rate=merged_left[['Email', 'Name','satifacotin_rate','id','full_name','First_response_time','unit']]
data_chat_satisfaction_rate['satifacotin_rate'] = round(data_chat_satisfaction_rate['satifacotin_rate'], 2)
user_list = []
for j in range(len(users_json)):
    for email  in agent_satisfaction['email']:
        if (users_json[j]['email']== email):
            user_list.append(j)
list_of_email = []
for i in user_list:
    list_of_email.append(users_json[i]['email'])

res = dict(zip(list_of_email, user_list)) 
users_list=pd.DataFrame.from_dict(res, orient='index',columns=['index']).reset_index()
users_list['Email'] = users_list['level_0']
data_chat_satisfaction_rate=pd.merge(left=agent_satisfaction, right=users_list, how='left', left_on='Email', right_on='Email')
#'Chat satisfaction rate - по каждому менеджеру CS'):
user_list = []
for j in range(len(users_json)):
    for email  in agent_satisfaction['email']:
        if (users_json[j]['email']== email):
            user_list.append(j)
            
for  satifacotin_rate,Name, val  in zip(data_chat_satisfaction_rate['satifacotin_rate'],data_chat_satisfaction_rate['Name'], data_chat_satisfaction_rate['index']):
    data = {
        "user": users_json[val] ,
        "description": Name,
        "value": round(satifacotin_rate,2),
        "date": today,
        "kpi_type": 15,#	Chat satisfaction rate - по каждому менеджеру CS
        "unit": ["Customer Success"],
        
    }
    bearer_token = 'Bearer '+ token
    headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())

# %%
#'First Response time - по каждому менеджеру CS'):
user_list = []
for j in range(len(users_json)):
    for email  in agent_satisfaction['email']:
        if (users_json[j]['email']== email):
            user_list.append(j)
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='First response time <60 sec (remote supp.) - по каждому менеджеру CS'):
        First_response_time_id = kpi_json[j]
            
for  rate,Name, val  in zip(data_chat_satisfaction_rate['First_response_time'],data_chat_satisfaction_rate['Name'], data_chat_satisfaction_rate['index']):
    data = {
        "user": users_json[val] ,
        "description": Name,
        "value": round(rate,2),
        "date": today,
        "kpi_type": 17,#First response time <60 sec (remote supp.) - по каждому менеджеру CS
        "unit": ["Customer Success"],
        
    }
    bearer_token = 'Bearer '+ token
    headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())
# Out:
# {'id': 308, 'user': {'id': 164, 'email': 'benita.nmeholam@latoken.com', 'full_name': 'Nmeholam Benita', 'role': [{'role': 'Manager Customer Success Satisfaction', 'id': 111, 'status': 'Hot search', 'problem_to_solve': 'Ensure Customers Success is scalable to a million daily users, with a quick problem solving and a few minutes KYC verification', 'requirement_skills_and_experience': 'English CR1, customer support experience, trading crypto experience, desire to grow as a specialist, sales experience, olympiad winner, fintech', 'keywords': 'fintech, customer support, sales b2c, trading', 'additional_comment': '', 'vacancy_link': 'https://ekaterinburg.hh.ru/vacancy/43492189', 'ideal_cv': 'https://drive.google.com/file/d/1q6Q45W135fGl_le7T-xQoP05Jf25WCWi/view?usp=sharing', 'manager_hiring': 157, 'hrbp': 335, 'main_performance_number': 'Customer satisfaction rate', 'second_performance_number': '1st response time in live chats', 'third_performance_number': ''}], 'unit': [{'unit': 'Customer
# ...

# %%
# то что берется не вручную get запросами

# %%
#total_chat_satisfaction_rate
# Ticket satisfaction rate - общий'):

start = "2021/03/01" # обязательно указывать дату начала
start= datetime.datetime.strptime(start, "%Y/%m/%d").timestamp()
end =  "2021/04/01"# дата конец на один день больше что бы вышел полный месяц
end = datetime.datetime.strptime(end, "%Y/%m/%d").timestamp()


# Set the request parameters
url = 'https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=bad&start_time={start}&end_time={end}'.format(start= int(start), end= int(end))
#url = 'https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?page[size]=110'#
#https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?page=2&start_time=1612137600',
user = 'assistant@latoken.com' + '/token'
pwd = 'gu8nyKWr6QgJEog5QfkmFhr9CQ0OukNuApgaDVP7'
session = requests.Session()
session.auth = (user, pwd)
#params = {'query': 'type:ticket status:closed brand:{brand_id}'}
#url = url + urlencode(params)
# ticket_results = []

response = session.get(url)
data_json=response.json()
data = data_json['satisfaction_ratings']
#data = pd.DataFrame.from_dict(data)
bad_data = pd.DataFrame.from_dict(data)
for i in range(2,9):
    #data = []
    i = str(i)
    url = "https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=bad&page="+i+"&start_time={start}&end_time={end}".format(start= int(start), end= int(end))
    response = session.get(url)
    data_json=response.json()
    data = data_json['satisfaction_ratings']
    data = pd.DataFrame.from_dict(data)
    bad_data = bad_data.append(data)
# Set the request parameters
url = 'https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=good&page=1&start_time={start}&end_time={end}'.format(start= int(start), end= int(end))
#url = 'https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?page[size]=110'#
#https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?page=2&start_time=1612137600',
user = 'assistant@latoken.com' + '/token'
pwd = 'gu8nyKWr6QgJEog5QfkmFhr9CQ0OukNuApgaDVP7'
session = requests.Session()
session.auth = (user, pwd)
#params = {'query': 'type:ticket status:closed brand:{brand_id}'}
#url = url + urlencode(params)
# ticket_results = []

response = session.get(url)
data_json=response.json()
data = data_json['satisfaction_ratings']
good_data = pd.DataFrame.from_dict(data)
for i in range(2,20):
    #data = []
    i = str(i)
    url = "https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=good&page="+i+"&start_time={start}&end_time={end}".format(start= int(start), end= int(end))
    #url = "https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=good&page="+i+"&start_time=1612137600&end_time=1614556799"
    #url = "https://latoken.zendesk.com/api/v2/satisfaction_ratings.json?score=good&page="+i+"&start_time=1612137600&end_time=1614556799"
    response = session.get(url)
    data_json=response.json()
    data = data_json['satisfaction_ratings']
    #data = pd.DataFrame.from_dict(data)
    good_data = good_data.append(data)
good_data=good_data.replace(['good'], 
                     [1]) 
bad_data=bad_data.replace(['bad'], 
                     [0]) 
good_data=good_data.rename(columns={"score": "good"})
bad_data=bad_data.rename(columns={"score": "bad"})

for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='Ticket satisfaction - общий'):
        total_ticket_satisfaction_id = kpi_json[j]['id']
total_ticket_satisfaction_score =round(((len(good_data)*100))/(len(good_data)+len(bad_data))/100, 2)
# total_ticket_satisfaction_score
data = {
        "description": 'Ticket satisfaction - общий',
        "value": total_ticket_satisfaction_score,
        "date": today,
        "kpi_type": total_ticket_satisfaction_id,
        "unit": ["Customer Success"]
    }
bearer_token = 'Bearer '+ token
headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
data = json.dumps(data)
#url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
#r = requests.post(url, headers=headers, data=data)
print(r.json())

# %%
# #total_chat_satisfaction_rate po dovzhenko.alexander@latoken.com тот же показатель но для dovzhenko.alexander@latoken.com
# # Ticket satisfaction rate - общий'):
# for j in range(len(kpi_json)):
#     if (kpi_json[j]['type']=='Ticket satisfaction - общий'):
#         total_ticket_satisfaction_id = kpi_json[j]['id']
# total_ticket_satisfaction_score =round(((len(good_data)*100))/(len(good_data)+len(bad_data))/100, 2)
# # total_ticket_satisfaction_score
# for j in range(len(users_json)):
#     if (users_json[j]['email']== 'dovzhenko.alexander@latoken.com'):# его нет в базе
#         dovzhenko_id = j
# data = {
#         "user":users_json[dovzhenko_id] ,#dovzhenko.alexander@latoken.com
#         "description": 'Ticket satisfaction - общий',
#         "value": total_ticket_satisfaction_score,
#         "date": today,
#         "kpi_type": total_ticket_satisfaction_id,
#         "unit": ["Customer Success"]
#     }
# bearer_token = 'Bearer '+ token
# headers = {'Authorization': bearer_token,
#               "Content-Type":"application/json"}
# data = json.dumps(data)
# url = 'https://ops-frontend.dev3.nekotal.tech/api/kpi-coefficient-values/'
# r = requests.post(url, headers=headers, data=data)

# %%
#next kpi

# %%
good_data=pd.pivot_table(good_data,index=["assignee_id"],values=["good"], aggfunc='count')
bad_data=pd.pivot_table(bad_data,index=["assignee_id"],values=["bad"], aggfunc='count')
data_ticket_satisfaction_rate = pd.concat([good_data, bad_data], axis=1, join="inner")
data_ticket_satisfaction_rate=data_ticket_satisfaction_rate.reset_index()
sum_column = data_ticket_satisfaction_rate["bad"] + data_ticket_satisfaction_rate["good"]
data_ticket_satisfaction_rate["sum"] = sum_column
satifacotin_rate =round(((data_ticket_satisfaction_rate["good"]*100)/data_ticket_satisfaction_rate["sum"])/100, 2)
data_ticket_satisfaction_rate["satifacotin_rate"] = satifacotin_rate
data_ticket_satisfaction_rate['assignee_id']=pd.to_numeric(data_ticket_satisfaction_rate['assignee_id'], downcast = 'integer')
headers = {
    'Authorization': 'Bearer MIEHGvBfoTB6vJmeeBzBN0ndv7ycfRNbSPGA5yWT2VsvHWcWm2BzuCNFyzmMGTBG',  
}
response = requests.get('https://www.zopim.com/api/v2/agents', headers=headers)
agents=response.json()
agents=pd.DataFrame.from_dict(agents)
data_ticket_satisfaction_rate= pd.concat([agents, data_ticket_satisfaction_rate], axis=1, join="inner")
data_ticket_satisfaction_rate=pd.merge(left=data_ticket_satisfaction_rate, right=users_list, how='inner', left_on='email', right_on='Email')
#'Chat satisfaction rate - по каждому менеджеру CS'):
# user_list = []
# for j in range(len(users_json)):
#     for email  in agent_satisfaction['email']:
#         if (users_json[j]['email']== email):
#             user_list.append(j)
for j in range(len(kpi_json)):
    if (kpi_json[j]['type']=='Ticket satisfaction - по каждому менеджеру CS'):
        ticket_satisfaction = kpi_json[j]['id']

for satifacotin_rate,Name,val  in zip(data_ticket_satisfaction_rate['satifacotin_rate'],data_ticket_satisfaction_rate['display_name'], data_ticket_satisfaction_rate['index']):
    data = {
        "user": users_json[val] ,
        "description": Name,
        "value": satifacotin_rate,
        "date": today,
        "kpi_type": 19,#	Ticket satisfaction - по каждому менеджеру CS
        "unit": ["Customer Success"]
    }
    bearer_token = 'Bearer '+ token
    headers = {'Authorization': bearer_token,
              "Content-Type":"application/json"}
    data = json.dumps(data)
    url = 'https://new.la-team.tk/api/kpi-coefficient-values/'
    r = requests.post(url, headers=headers, data=data)
    print(r.json())

# %%
##////////////////////не нужные показатели оставлю просто шаблон в случаи не понятных ситуаций, использовать для загрузки
