# %% [markdown]
# <a href="https://colab.research.google.com/github/igorvojnyak/datavojnyak.github.io/blob/master/task_for_the_Data_Science_NLP_Intern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymorphy2
# Out:
# Requirement already satisfied: pymorphy2 in /usr/local/lib/python3.6/dist-packages (0.8)
# Requirement already satisfied: dawg-python>=0.7 in /usr/local/lib/python3.6/dist-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts<3.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from pymorphy2) (2.4.393442.3710985)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.6/dist-packages (from pymorphy2) (0.6.2)

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.6/dist-packages (0.0.25)
# Requirement already satisfied: textsearch in /usr/local/lib/python3.6/dist-packages (from contractions) (0.0.17)
# Requirement already satisfied: Unidecode in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.1.1)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.4.0)

# %%
pip install pyaspeller
# Out:
# Requirement already satisfied: pyaspeller in /usr/local/lib/python3.6/dist-packages (0.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from pyaspeller) (1.15.0)

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.6/dist-packages (0.0.25)
# Requirement already satisfied: textsearch in /usr/local/lib/python3.6/dist-packages (from contractions) (0.0.17)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.4.0)
# Requirement already satisfied: Unidecode in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.1.1)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
import logging
import pandas as pd
import numpy as np
from numpy import random
import nltk
from nltk.tokenize import word_tokenize
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from nltk.stem.snowball import SnowballStemmer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
# %matplotlib inline
import spacy
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
#from contractions import contractions_dict
#import contractions
import unicodedata
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
import requests
from bs4 import BeautifulSoup
from sklearn.externals import joblib
import json
from string import punctuation
from nltk.corpus import stopwords
#stopwords.words('russian')
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
from pyaspeller import YandexSpeller
import nltk
import re
from nltk.stem import WordNetLemmatizer 
import pymorphy2
from nltk.corpus import stopwords
#from stop_words import get_stop_words
nltk.download('stopwords')
nltk.download('punkt')
import os 
import json
import numpy as np
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import make_pipeline

import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
# %matplotlib inline
import spacy
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
from contractions import contractions_dict
import contractions
import unicodedata
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
import requests
from bs4 import BeautifulSoup
from sklearn.externals import joblib
import json
from string import punctuation
from nltk.corpus import stopwords
#stopwords.words('russian')
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
from pyaspeller import YandexSpeller
import nltk
import re
from nltk.stem import WordNetLemmatizer 
import pymorphy2
from nltk.corpus import stopwords
#from stop_words import get_stop_words
nltk.download('stopwords')
nltk.download('punkt')
import os 
import json
import numpy as np
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import make_pipeline

import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pip install stop_words
# Out:
# Requirement already satisfied: stop_words in /usr/local/lib/python3.6/dist-packages (2018.7.23)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
import logging
import pandas as pd
import numpy as np
from numpy import random
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from nltk.stem.snowball import SnowballStemmer

# %%
from stop_words import get_stop_words
from nltk.corpus import stopwords
import nltk
from stop_words import get_stop_words
nltk.download('stopwords')
nltk.download('punkt')
stop_words = list(get_stop_words('ru')) 
nltk_words = list(stopwords.words('russian')) 
stop_words.extend(nltk_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/lenta-ru-news.csv')

# %%
#Grammar
# text=[w for w in df['text']]
# changes = {change['word']: change['s'][0] for change in speller.spell(text)}
# for word, suggestion in changes.items():
#     text = [ item.replace(word, suggestion) for item in text]
# df['text'] = pd.DataFrame(text)

# %%
df=df[:200975]

# %%
import re 
r =  re.compile("[а-яА-Я]+")
def preprocessing(line):
    line = line.lower()
    line = re.sub(r"[{}]".format(string.punctuation), " ", line)
    return line
def remove_num(text):
    return(''.join(ch for ch in text if not ch.isdigit()))
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^а-яА-Я+0-9\s]' if not remove_digits else r'[^а-яА-Я+\s]'
    text = re.sub(pattern, '', text)
    return text

# %%
df['text'] = df['text'].astype(str)

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.snowball import RussianStemmer
#df['text'] = df['text'].apply(remove_special_characters)
#df['stemm']= df['text'].apply(lambda x: ''.join([stemmer.stem(word) for word in x]))
#data['text'] = [w for w in filter(r.match, data['text'])]
df['text']= df['text'].apply(preprocessing)
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in r.findall(x.lower())]))
df['text'] =  df['text'].apply(lambda x:  ' '.join([contractions.fix(word) for word in x.split()]))
df['text'] = df['text'].apply(remove_num)
df['text'] =  df['text'].apply(lambda x: ''.join([word for word in x if word not in punctuation]))

# %%
df['text_no_swords']=df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
df['length'] = df['text_no_swords'].apply(len)
df['length'] = df['length'].replace(0,np.nan)
df['length'].plot(bins=90, kind='hist') 
plt.xlabel('words', fontsize=15)
plt.ylabel('length of words in 1 text', fontsize=10)
# Out:
# Text(0, 0.5, 'length of words in 1 text')

# %%
from collections import Counter
import nltk
import string
from nltk.tokenize import word_tokenize

# %%
corpus=[]
new= df['text_no_swords'].str.split()
new=new.values.tolist()
corpus=[word for i in new for word in i]
counter=Counter(corpus)
most=counter.most_common()
x, y= [], []
for word,count in most[:15]:
    if (word not in stop_words):
        x.append(word)
        y.append(count)
plt.figure(figsize=(20,10))
sns.barplot(x=y,y=x,)

# %%
df.groupby('topic').count()[['tags']]
# Out:
#                      tags
# topic
# 69-я параллель       1268
# Библиотека             65
# Бизнес               7375
# Бывший СССР         51370
# Дом                 21734
# Из жизни            27513
# Интернет и СМИ      44421
# Крым                  666
# Культпросвет          340
# Культура            53531
# Легпром               114
# МедНовости              1
# Мир                136621
# Наука и техника     53136
# Оружие                  3
# Путешествия          6370
# Россия             155007
# Силовые структуры   11223
# Сочи                    1
# Спорт               57894
# Ценности             7581
# ЧМ-2014                 2
# Экономика           76423

# %%
labels=df['tags'].unique()

# %%
plt.figure(figsize=(20,150))
plt.title('Percentage of tags', fontsize=20)
df.tags.value_counts().plot(kind='pie',
                              wedgeprops=dict(width=.8), autopct='%1.0f%%', startangle= -20, 
                              textprops={'fontsize': 15})
plt.legend(labels)

# %%
columns = list(df.groupby('topic').count()[['tags']].index)

fig, ax = plt.subplots(figsize=(14, 8))

sns.set(style="whitegrid")
sns.set_context("notebook", font_scale=1.5)
sns.despine()

ax = sns.barplot(x=columns, y='tags', data=df.groupby('topic').count()[['tags']], palette=("viridis"))
ax.set_title(label='topics', fontweight='bold', size=18, pad=20)
plt.ylabel('Number of tags', fontsize=16)
plt.xticks(rotation=90)
plt.tight_layout()

# %%
nmf_x = df['topic'].value_counts()
nmf_y = nmf_x.sort_index()
plt.figure(figsize=(50,30))
sns.barplot(nmf_x, nmf_y.index)
plt.title("topic Distribution", fontsize=50)
plt.ylabel('Review Topics', fontsize=50)
plt.yticks(fontsize=40)
plt.xlabel('Frequency', fontsize=50)
plt.xticks(fontsize=40)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.,
#         140000., 160000., 180000.]),
#  <a list of 10 Text major ticklabel objects>)

# %%
sns.boxplot(x='length',data=df,palette='rainbow')

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
df['token']=df['text_no_swords'].apply(word_tokenize)
def normalForm(line):
    return [morph.parse(word)[0].normal_form for word in line if len(word)>2]

# %%
df['token'] = [normalForm(word) for word in df['token']]

# %%
from nltk.util import ngrams

# %%
def get_top_ngram(corpus):
    vec = TfidfVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) 
                  for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:50]
#top_n_bigrams=get_top_ngram(df['text_no_swords'])
x,y=map(list,zip(*get_top_ngram(df['text_no_swords'])))
plt.figure(figsize=(40,20))
sns.barplot(x=y,y=x)

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
detokenized_doc = []
for i in range(len(df)):
    t = ' '.join(df.token[i])
    detokenized_doc.append(t)

df['clean_doc'] = detokenized_doc

# %%
Vectorizer = TfidfVectorizer(ngram_range=(2,2))
termFrequency = Vectorizer.fit_transform(df['clean_doc'])
featureNames = Vectorizer.get_feature_names()

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD

# %%
def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
trn = TruncatedSVD(n_components=5,n_iter=7, random_state=1).fit(termFrequency)

# %%
display_topics(trn, featureNames, 10)
# Out:
#             Topic 0 words  ... Topic 4 weights
# 0             риа новости  ...             0.6
# 1            сообщает риа  ...             0.2
# 2            передает риа  ...             0.2
# 3         новости ссылкой  ...             0.2
# 4            сообщили риа  ...             0.2
# 5          уголовное дело  ...             0.1
# 6           агентство риа  ...             0.1
# 7            пресс службе  ...             0.1
# 8          владимир путин  ...             0.1
# 9  предварительным данным  ...             0.1
#
# [10 rows x 10 columns]

# %%
nmf = NMF(n_components=5, random_state=0, alpha=.1, l1_ratio=.5, init='nndsvd').fit(termFrequency)

# %%
display_topics(nmf, featureNames, 10)
# Out:
#             Topic 0 words  ... Topic 4 weights
# 0             риа новости  ...             3.7
# 1            сообщает риа  ...             1.6
# 2            передает риа  ...             1.5
# 3         новости ссылкой  ...             1.0
# 4            сообщили риа  ...             0.8
# 5           агентство риа  ...             0.7
# 6            пресс службе  ...             0.7
# 7          владимир путин  ...             0.5
# 8  предварительным данным  ...             0.5
# 9           новости пресс  ...             0.5
#
# [10 rows x 10 columns]

# %%
lda = LatentDirichletAllocation(n_components=5).fit(termFrequency)

# %%
display_topics(lda, featureNames, 10)
# Out:
#         Topic 0 words Topic 0 weights  ...       Topic 4 words Topic 4 weights
# 0         риа новости           224.2  ...         риа новости           210.9
# 1        сообщает риа           132.5  ...        сообщает риа           120.0
# 2       таким образом            67.8  ...           итар тасс            97.7
# 3  сообщает интерфакс            66.5  ...       таким образом            67.6
# 4  сообщает агентство            64.6  ...  миллиарда долларов            67.4
# 5      уголовное дело            61.0  ...  сообщает интерфакс            66.2
# 6           итар тасс            60.9  ...  сообщает агентство            62.8
# 7        передает риа            60.2  ...      уголовное дело            59.6
# 8  передает агентство            56.8  ...        передает риа            57.7
# 9     пункта процента            51.8  ...  передает агентство            54.6
#
# [10 rows x 10 columns]

# %%
print("Log likelihood: ", lda.score(termFrequency))
# Out:
# Log likelihood:  -36365943.90405538

# %%
print("Perplexity: ", lda.perplexity(termFrequency))
# Out:
# Perplexity:  96822670.74845193

# %%
from sklearn.model_selection import GridSearchCV
search_params = {'n_components': [ 5, 10, 15], 'learning_decay': [.5, .7]}
lda = LatentDirichletAllocation()
model = GridSearchCV(lda, search_params)
model.fit(termFrequency)
best_lda_model = model.best_estimator_
print("Best model's params: ", model.best_params_)
print("Best log likelihood score: ", model.best_score_)
print("Model perplexity: ", best_lda_model.perplexity(termFrequency))
