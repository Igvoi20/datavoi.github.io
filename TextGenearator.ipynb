# %% [markdown]
# <a href="https://colab.research.google.com/github/igorvojnyak/datavojnyak.github.io/blob/master/TextGenearator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyyaml h5py  # Требуется для сохранения модели в формате HDF5
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
pip install meduza
# Out:
# Collecting meduza
#   Downloading https://files.pythonhosted.org/packages/f3/8c/74fbd754c670810641a47be828019ba32f1b9649720db5f479dac90c0e23/meduza-20.7.2.tar.gz
# Building wheels for collected packages: meduza
#   Building wheel for meduza (setup.py) ... done
#   Created wheel for meduza: filename=meduza-20.7.2-cp36-none-any.whl size=4599 sha256=69713e8e9ab99f6b28fedec391c50e938b091b288ad70b089af81cacb38c816d
#   Stored in directory: /root/.cache/pip/wheels/a6/b6/0e/885bd0b8bfbcf2d1fabe0c19372d99f52a37d2f062bf2e2a22
# Successfully built meduza
# Installing collected packages: meduza
# Successfully installed meduza-20.7.2

# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading https://files.pythonhosted.org/packages/de/9e/9050199ac7cbc755d1c49577fdaa5517901124b574264b3602a8b8028440/newsapi_python-0.2.6-py2.py3-none-any.whl
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from newsapi-python) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->newsapi-python) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->newsapi-python) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->newsapi-python) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->newsapi-python) (1.24.3)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.6

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
import re
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
import logging
import pandas as pd
import json
import numpy as np
from numpy import random
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
import gensim
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
import json
import numpy
import sys
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
import requests
import pandas as pd
from pandas.io.json import json_normalize 
import json
from bs4 import BeautifulSoup
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import meduza
from string import punctuation
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from nltk.stem.snowball import SnowballStemmer
import tensorflow as tf
import numpy as np
import os
import pickle
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from string import punctuation

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
# filename = "/content/d.txt"
# raw_text = open(filename, 'r', encoding='utf-8').read()
# raw_text = raw_text.lower()
# text =re.sub(r"[#%«!@»—A-Za-z*]", "", raw_text) 
# raw_text = raw_text.translate(str.maketrans("", "", punctuation))

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
import requests
url = ('https://newsapi.org/v2/everything?q=новости&apiKey=49966f3d107f48ce904d1d8dda75ddbd')
response = requests.get(url)
json_data = response.json()
data = pd.DataFrame(columns=['titles'])
result = []
for title in json_data["articles"]:
    result.append(title['title'])
    #print(title['title'])
    result.append(title['description'])
    # for extr_title in title['title']:
    #     #result.extend(extr_title)
    #     print('efe')

        #df['titles'] = result
        #file_object = open('/content/data.txt', 'a')
        #file_object.write(" ")
        #file_object.write(remove_html_tags(extr_title))
    # for extr_description in title['description']: 
    #     result.append(extr_description)
        #file_object = open('/content/data.txt', 'a')
        #file_object.write(" ")
        #file_object.write(remove_html_tags (extr_description))

        

#file_object.close()

# %%
def get_titles(url):
    r = requests.get(url)
    html = BeautifulSoup(r.content, 'html.parser')
    table = html.find_all("title")
    description = html.find_all("description")
    for title in table:
        #df['titles']= title.text
        result.append(title.text)
        #file_object = open('/content/data.txt', 'a')
        #file_object.write(title.text)
        #file_object.write(" ")
    for descr in description:
        #df['titles']= descr.text
        result.append(descr.text)
        #file_object = open('/content/data.txt', 'a')
        #file_object.write(descr.text)
        #file_object.write(" ")
    
    #file_object.close()

# %%
get_titles('https://lenta.ru/rss/articles')
get_titles('https://news.yandex.ru/politics.rss')
get_titles('https://meduza.io/rss2/all')
get_titles('https://www.liga.net/news/all/rss.xml')
get_titles('https://rg.ru/tema/gos/rss.xml')
get_titles('https://rg.ru/xml/index.xml')
get_titles('http://k.img.com.ua/rss/ru/russia.xml')
get_titles('http://k.img.com.ua/rss/ru/all_news2.0.xml')
get_titles('https://rss.newsru.com/world')
get_titles('https://gordonua.com/xml/rss.html')
get_titles('https://www.sostav.ru/rss')
get_titles('https://news.mail.ru/rss/economics/')
get_titles('https://www.vesti.ru/vesti.rss')
get_titles('https://news.mail.ru/rss/society/')
get_titles('https://news.yandex.ru/world.rss')
get_titles('https://news.mail.ru/rss/politics/')
get_titles('https://news.mail.ru/rss/')
get_titles('https://news.mail.ru/rss/main/')
get_titles('https://news.rambler.ru/rss/world/')
get_titles('https://news.rambler.ru/rss/articles/')
get_titles('https://news.rambler.ru/rss/Moscow/')
get_titles('https://news.rambler.ru/rss/moscow_city/')
get_titles('https://ria.ru/export/rss2/archive/index.xml')
get_titles('https://lenta.ru/rss/articles')
get_titles('https://lenta.ru/rss/news/russia')
get_titles('https://lenta.ru/rss/last24')
get_titles('https://lenta.ru/rss/top7')
get_titles('https://lenta.ru/rss/articles/russia')

# %%
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key='49966f3d107f48ce904d1d8dda75ddbd')
all_articles = newsapi.get_everything(q='новости',
                                      language='ru',
                                      sort_by='relevancy',
                                      page=5)
for title in all_articles["articles"]:
    #print(title['title'])
    titles = remove_html_tags(title['description'])
    result.append(titles)
    #print(titles)
    #for extr_title in titles:
        #file_object = open('/content/data.txt', 'a')
        #file_object.write(extr_title)
        #file_object.write(" ")

    #file_object.close()

# %%
url = "https://meduza.io/en/brief/2020/11/07/the-real-russia-today"
article = meduza.get(url)
#data = []
for article in meduza.section('news', n=1000, lang='ru'):
    #print(article['title'])
    result.append(article['title'])
    #data.append(f" '{article['title']}'")
    #file_object = open('/content/data.txt', 'a')
    #file_object.write(f" '{article['title']}'")
    

# Close the file
#file_object.close()

# %%
data = pd.DataFrame(columns=['text'])

# %%
data['text'] = result

# %%
#import the data
#data_path = 'C:/Users/Downloads/.....csv'
#data = pd.read_csv(data_path)

#Function to clean the text
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = text.lower()
    #text = text.replace('\%','')
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text =re.sub(r"[xxx:\r\n\n£'→❤🎩😎#№\u200e\u202f\xa0«»%«!@»—A-Za-z*]", "", text)
    text = re.sub('<.*?>+', '', text)
    text =re.sub("\xa0£", "", text) 
    text = re.sub('[%s]' % re.escape(punctuation), '', text)
    text = re.sub('\n', '', text)
    bad_chars = ['+',';', ':', '!', "*","\xa0"]
    for i in bad_chars :
        text = text.replace(i, '')
    data = text.translate(str.maketrans("", "", punctuation))
    text = re.sub('\w*\d\w*', '', text)
    text = " ".join(filter(lambda x:x[0]!="@", text.split()))
    return text

#Apply the function
data['text'] = data['text'].apply(lambda x: clean_text(x))
data = data['text']

# %%
data.head(50)
# Out:
# 0                                  новости из вселенной
# 1     октября состоялась небольшая онлайнконференция...
# 2                                        новости выпуск
# 3     новости выпуск привет это очередной выпуск нов...
# 4     новости стартапов и венчура реальные сроки за ...
# 5     привет хабр раз в неделю я рассказываю о крупн...
# 6                             хорошие новости из томска
# 7     сегодня утром оперативники следственного комит...
# 8                                            новости ит
# 9     видео на ютубтекстовая версияв капсуле прокати...
# 10                                     новые новости ит
# 11    видео на ютубтекстовая версияосенью для айтишн...
# 12                          новости украинской политики
# 13    оля полякова и киркоров спели вместе в дубаях ...
# 14                             не очень хорошие новости
# 15    над арменией был сбит всего один российский ве...
# 16                         в этой новости прекрасно всё
# 17    в петербурге суд рассмотрел иск женщины котора...
# 18               биография олега меньшикова риа новости
# 19    биография олега меньшиковариа новостименьшиков...
# 20                        умер роман виктюк риа новости
# 21    умер роман виктюкриа новостирежиссер роман вик...
# 22           трампа обязательно предадут рамблерновости
# 23    трампа обязательно предадутрамблерновостиштаб ...
# 24                    акции о подскочили рамблерновости
# 25    акции о подскочилирамблерновости объявил цену ...
# 26    зеленский будет ежедневно рассказывать новости...
# 27    президент украины владимир зеленский заявил чт...
# 28    аспирин при коронавирусе можно или нет новости...
# 29    аспирин при коронавирусе можно или нет новости...
# 30                                               цитата
# 31    мама читая новости больше всего конечно арбале...
# 32              новостной дайджест событий из мира плис
# 33    здравствуйте друзья продолжаем публикации посл...
# 34            выборывыборами а новости ит по расписанию
# 35    видео на фейсбуктекстовая версия под катомиз б...
# 36         в ньюйорке начали праздновать победу байдена
# 37    в центре ньюйорка американцы начали отмечать п...
# 38    турция захотела производить у себя российскую ...
# 39    турция захотела производить у себя российскую ...
# 40                                               статьи
# 41
# 42    гангстеры расизм и ничего хорошего каким получ...
# 43    зачем сталин завладел прибалтикой и что с ней ...
# 44    почему богатые люди тратят тысячи долларов на ...
# 45    на любимом курорте россиян дефицит жилья где в...
# 46    азербайджанцы возвращаются в карабах смогут ли...
# 47     откроет сеть зарядных станций для электромобилей
# 48    как проект активный гражданин помогает жителям...
# 49      как начать и развить свое дело с помощью москвы
# Name: text, dtype: object

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
total_words = len(tokenizer.word_index) + 1
print(total_words) 
input_sequences = []
for line in data:
	token_list = tokenizer.texts_to_sequences([line])[0]
	for i in range(1, len(token_list)):
		n_gram_sequence = token_list[:i+1]
		input_sequences.append(n_gram_sequence)
# Out:
# 16152

# %%
max_sequence_length = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre'))

# %%
# create predictors and label
xs, labels = input_sequences[:,:-1],input_sequences[:,-1]
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)

# %%
model = Sequential()
model.add(Embedding(total_words, 80, input_length=max_sequence_length-1))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(tf.keras.layers.Dropout(0.1))
model.add(Dense(total_words/20))
model.add(Dense(total_words, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 106, 80)           1292160
# _________________________________________________________________
# lstm (LSTM)                  (None, 106, 100)          72400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 807)               41157
# _________________________________________________________________
# dense_1 (Dense)              (None, 16152)             13050816
# =================================================================
# Total params: 14,486,733
# Trainable params: 14,486,733
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

#checkpoint_path = "/content/drive/MyDrive/training_1/cp.ckpt"
#checkpoint_dir = os.path.dirname(checkpoint_path)

# Создаем коллбек сохраняющий веса модели
# = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                #  save_best_only=True,
                                                #  verbose=1, mode='min')
filepath="/content/drive/MyDrive/weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# Обучаем модель с новым коллбеком
# model.fit(train_images, 
#           train_labels,  
#           epochs=10,
#           validation_data=(test_images,test_labels),
#           callbacks=callbacks_list)  # Pass callback to training

# Это может генерировать предупреждения относящиеся к сохранению состояния оптимизатора.
# Эти предупреждения (и подобные предупреждения в этом уроке)
# используются для предотвращения устаревшего использования и могут быть проигнорированы.
history = model.fit(xs, ys, epochs=200, verbose=1,callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.8720
# Epoch 00001: loss improved from inf to 0.50118, saving model to /content/drive/MyDrive/weights-improvement-01-0.5012-bigger.hdf5
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.5012 - accuracy: 0.8720
# Epoch 2/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.4773 - accuracy: 0.8763
# Epoch 00002: loss improved from 0.50118 to 0.47731, saving model to /content/drive/MyDrive/weights-improvement-02-0.4773-bigger.hdf5
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.4773 - accuracy: 0.8763
# Epoch 3/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3629 - accuracy: 0.9022
# Epoch 00003: loss improved from 0.47731 to 0.36290, saving model to /content/drive/MyDrive/weights-improvement-03-0.3629-bigger.hdf5
# 1569/1569 [==============================] - 46s 29ms/step - loss: 0.3629 - accuracy: 0.9022
# Epoch 4/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.9061
# Epoch 00004: loss improved from 0.36290 to 0.35396, saving model to /content/drive/MyDrive/weights-improvement-04-0.3540-bigger.hdf5
# 1569/1569 [==============================] - 46s 30ms/step - loss: 0.3540 - accuracy: 0.9061
# Epoch 5/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3611 - accuracy: 0.9027
# Epoch 00005: loss did not improve from 0.35396
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3611 - accuracy: 0.9027
# Epoch 6/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.9062
# Epoch 00006: loss improved from 0.35396 to 0.35149, saving model to /content/drive/MyDrive/weights-improvement-06-0.3515-bigger.hdf5
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3515 - accuracy: 0.9062
# Epoch 7/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3495 - accuracy: 0.9059
# Epoch 00007: loss improved from 0.35149 to 0.34941, saving model to /content/drive/MyDrive/weights-improvement-07-0.3494-bigger.hdf5
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3494 - accuracy: 0.9059
# Epoch 8/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3475 - accuracy: 0.9066
# Epoch 00008: loss improved from 0.34941 to 0.34750, saving model to /content/drive/MyDrive/weights-improvement-08-0.3475-bigger.hdf5
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3475 - accuracy: 0.9066
# Epoch 9/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3533 - accuracy: 0.9048
# Epoch 00009: loss did not improve from 0.34750
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3533 - accuracy: 0.9048
# Epoch 10/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.9075
# Epoch 00010: loss improved from 0.34750 to 0.34514, saving model to /content/drive/MyDrive/weights-improvement-10-0.3451-bigger.hdf5
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3451 - accuracy: 0.9075
# Epoch 11/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.9070
# Epoch 00011: loss did not improve from 0.34514
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3463 - accuracy: 0.9070
# Epoch 12/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3486 - accuracy: 0.9062
# Epoch 00012: loss did not improve from 0.34514
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3486 - accuracy: 0.9062
# Epoch 13/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.9088
# Epoch 00013: loss improved from 0.34514 to 0.33575, saving model to /content/drive/MyDrive/weights-improvement-13-0.3357-bigger.hdf5
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3357 - accuracy: 0.9088
# Epoch 14/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.9091
# Epoch 00014: loss did not improve from 0.33575
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3379 - accuracy: 0.9091
# Epoch 15/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3435 - accuracy: 0.9083
# Epoch 00015: loss did not improve from 0.33575
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3435 - accuracy: 0.9083
# Epoch 16/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.9090
# Epoch 00016: loss did not improve from 0.33575
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3372 - accuracy: 0.9090
# Epoch 17/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.9094
# Epoch 00017: loss did not improve from 0.33575
# 1569/1569 [==============================] - 43s 28ms/step - loss: 0.3361 - accuracy: 0.9094
# Epoch 18/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.9095
# Epoch 00018: loss improved from 0.33575 to 0.33205, saving model to /content/drive/MyDrive/weights-improvement-18-0.3320-bigger.hdf5
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3320 - accuracy: 0.9095
# Epoch 19/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3322 - accuracy: 0.9111
# Epoch 00019: loss did not improve from 0.33205
# 1569/1569 [==============================] - 45s 29ms/step - loss: 0.3322 - accuracy: 0.9111
# Epoch 20/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.9104
# Epoch 00020: loss did not improve from 0.33205
# 1569/1569 [==============================] - 45s 28ms/step - loss: 0.3342 - accuracy: 0.9104
# Epoch 21/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3362 - accuracy: 0.9093
# Epoch 00021: loss did not improve from 0.33205
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3363 - accuracy: 0.9092
# Epoch 22/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3192 - accuracy: 0.9130
# Epoch 00022: loss improved from 0.33205 to 0.31922, saving model to /content/drive/MyDrive/weights-improvement-22-0.3192-bigger.hdf5
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3192 - accuracy: 0.9130
# Epoch 23/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.9099
# Epoch 00023: loss did not improve from 0.31922
# 1569/1569 [==============================] - 45s 28ms/step - loss: 0.3319 - accuracy: 0.9099
# Epoch 24/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3279 - accuracy: 0.9110
# Epoch 00024: loss did not improve from 0.31922
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3279 - accuracy: 0.9111
# Epoch 25/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.9115
# Epoch 00025: loss did not improve from 0.31922
# 1569/1569 [==============================] - 44s 28ms/step - loss: 0.3255 - accuracy: 0.9115
# Epoch 26/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.9116
# Epoch 00026: loss did not improve from 0.31922
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.3265 - accuracy: 0.9116
# Epoch 27/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3256 - accuracy: 0.9118
# Epoch 00027: loss did not improve from 0.31922
# 1569/1569 [==============================] - 43s 28ms/step - loss: 0.3256 - accuracy: 0.9118
# Epoch 28/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3172 - accuracy: 0.9143
# Epoch 00028: loss improved from 0.31922 to 0.31735, saving model to /content/drive/MyDrive/weights-improvement-28-0.3174-bigger.hdf5
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.3174 - accuracy: 0.9143
# Epoch 29/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.9105
# Epoch 00029: loss did not improve from 0.31735
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3262 - accuracy: 0.9105
# Epoch 30/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.9141
# Epoch 00030: loss did not improve from 0.31735
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.3174 - accuracy: 0.9141
# Epoch 31/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3178 - accuracy: 0.9127
# Epoch 00031: loss did not improve from 0.31735
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3178 - accuracy: 0.9127
# Epoch 32/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3177 - accuracy: 0.9140
# Epoch 00032: loss did not improve from 0.31735
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3180 - accuracy: 0.9139
# Epoch 33/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3195 - accuracy: 0.9122
# Epoch 00033: loss did not improve from 0.31735
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3199 - accuracy: 0.9121
# Epoch 34/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3225 - accuracy: 0.9119
# Epoch 00034: loss did not improve from 0.31735
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3225 - accuracy: 0.9119
# Epoch 35/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3147 - accuracy: 0.9142
# Epoch 00035: loss improved from 0.31735 to 0.31476, saving model to /content/drive/MyDrive/weights-improvement-35-0.3148-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3148 - accuracy: 0.9142
# Epoch 36/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3155 - accuracy: 0.9137
# Epoch 00036: loss did not improve from 0.31476
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3156 - accuracy: 0.9137
# Epoch 37/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9171
# Epoch 00037: loss improved from 0.31476 to 0.30912, saving model to /content/drive/MyDrive/weights-improvement-37-0.3091-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3091 - accuracy: 0.9171
# Epoch 38/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.9142
# Epoch 00038: loss did not improve from 0.30912
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3161 - accuracy: 0.9142
# Epoch 39/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3106 - accuracy: 0.9157
# Epoch 00039: loss did not improve from 0.30912
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3104 - accuracy: 0.9157
# Epoch 40/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3126 - accuracy: 0.9162
# Epoch 00040: loss did not improve from 0.30912
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3125 - accuracy: 0.9163
# Epoch 41/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3089 - accuracy: 0.9154
# Epoch 00041: loss improved from 0.30912 to 0.30907, saving model to /content/drive/MyDrive/weights-improvement-41-0.3091-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3091 - accuracy: 0.9154
# Epoch 42/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3081 - accuracy: 0.9162
# Epoch 00042: loss improved from 0.30907 to 0.30806, saving model to /content/drive/MyDrive/weights-improvement-42-0.3081-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3081 - accuracy: 0.9162
# Epoch 43/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3135 - accuracy: 0.9151
# Epoch 00043: loss did not improve from 0.30806
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3134 - accuracy: 0.9151
# Epoch 44/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9161
# Epoch 00044: loss did not improve from 0.30806
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3109 - accuracy: 0.9161
# Epoch 45/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3123 - accuracy: 0.9144
# Epoch 00045: loss did not improve from 0.30806
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3123 - accuracy: 0.9143
# Epoch 46/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2983 - accuracy: 0.9184
# Epoch 00046: loss improved from 0.30806 to 0.29830, saving model to /content/drive/MyDrive/weights-improvement-46-0.2983-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2983 - accuracy: 0.9184
# Epoch 47/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3109 - accuracy: 0.9151
# Epoch 00047: loss did not improve from 0.29830
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.3110 - accuracy: 0.9151
# Epoch 48/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.9167
# Epoch 00048: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3074 - accuracy: 0.9167
# Epoch 49/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.3003 - accuracy: 0.9178
# Epoch 00049: loss did not improve from 0.29830
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.3004 - accuracy: 0.9178
# Epoch 50/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3052 - accuracy: 0.9158
# Epoch 00050: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3052 - accuracy: 0.9157
# Epoch 51/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3008 - accuracy: 0.9186
# Epoch 00051: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3009 - accuracy: 0.9185
# Epoch 52/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2992 - accuracy: 0.9174
# Epoch 00052: loss did not improve from 0.29830
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2992 - accuracy: 0.9174
# Epoch 53/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3012 - accuracy: 0.9176
# Epoch 00053: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3013 - accuracy: 0.9176
# Epoch 54/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3027 - accuracy: 0.9175
# Epoch 00054: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3027 - accuracy: 0.9175
# Epoch 55/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.9177
# Epoch 00055: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3003 - accuracy: 0.9177
# Epoch 56/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3002 - accuracy: 0.9185
# Epoch 00056: loss did not improve from 0.29830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3001 - accuracy: 0.9185
# Epoch 57/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2977 - accuracy: 0.9185
# Epoch 00057: loss improved from 0.29830 to 0.29772, saving model to /content/drive/MyDrive/weights-improvement-57-0.2977-bigger.hdf5
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.2977 - accuracy: 0.9185
# Epoch 58/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2962 - accuracy: 0.9187
# Epoch 00058: loss improved from 0.29772 to 0.29616, saving model to /content/drive/MyDrive/weights-improvement-58-0.2962-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2962 - accuracy: 0.9187
# Epoch 59/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2928 - accuracy: 0.9197
# Epoch 00059: loss improved from 0.29616 to 0.29275, saving model to /content/drive/MyDrive/weights-improvement-59-0.2928-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2928 - accuracy: 0.9197
# Epoch 60/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.9166
# Epoch 00060: loss did not improve from 0.29275
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.3005 - accuracy: 0.9166
# Epoch 61/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2957 - accuracy: 0.9190
# Epoch 00061: loss did not improve from 0.29275
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2959 - accuracy: 0.9189
# Epoch 62/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 0.9195
# Epoch 00062: loss did not improve from 0.29275
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2932 - accuracy: 0.9195
# Epoch 63/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.3004 - accuracy: 0.9182
# Epoch 00063: loss did not improve from 0.29275
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.3005 - accuracy: 0.9181
# Epoch 64/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2936 - accuracy: 0.9206
# Epoch 00064: loss did not improve from 0.29275
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2935 - accuracy: 0.9206
# Epoch 65/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2900 - accuracy: 0.9199
# Epoch 00065: loss improved from 0.29275 to 0.28990, saving model to /content/drive/MyDrive/weights-improvement-65-0.2899-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2899 - accuracy: 0.9199
# Epoch 66/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.9204
# Epoch 00066: loss improved from 0.28990 to 0.28947, saving model to /content/drive/MyDrive/weights-improvement-66-0.2895-bigger.hdf5
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2895 - accuracy: 0.9204
# Epoch 67/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2963 - accuracy: 0.9188
# Epoch 00067: loss did not improve from 0.28947
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2964 - accuracy: 0.9188
# Epoch 68/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.9194
# Epoch 00068: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2940 - accuracy: 0.9194
# Epoch 69/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.9197
# Epoch 00069: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2948 - accuracy: 0.9197
# Epoch 70/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.9212
# Epoch 00070: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2904 - accuracy: 0.9212
# Epoch 71/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2905 - accuracy: 0.9209
# Epoch 00071: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2906 - accuracy: 0.9209
# Epoch 72/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2911 - accuracy: 0.9195
# Epoch 00072: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2912 - accuracy: 0.9194
# Epoch 73/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2919 - accuracy: 0.9195
# Epoch 00073: loss did not improve from 0.28947
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2920 - accuracy: 0.9195
# Epoch 74/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2851 - accuracy: 0.9224
# Epoch 00074: loss improved from 0.28947 to 0.28514, saving model to /content/drive/MyDrive/weights-improvement-74-0.2851-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2851 - accuracy: 0.9223
# Epoch 75/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.9215
# Epoch 00075: loss did not improve from 0.28514
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2872 - accuracy: 0.9215
# Epoch 76/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2878 - accuracy: 0.9206
# Epoch 00076: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2879 - accuracy: 0.9205
# Epoch 77/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2940 - accuracy: 0.9194
# Epoch 00077: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2940 - accuracy: 0.9194
# Epoch 78/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2902 - accuracy: 0.9209
# Epoch 00078: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2901 - accuracy: 0.9209
# Epoch 79/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2854 - accuracy: 0.9217
# Epoch 00079: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2855 - accuracy: 0.9217
# Epoch 80/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.9213
# Epoch 00080: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2868 - accuracy: 0.9213
# Epoch 81/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2920 - accuracy: 0.9204
# Epoch 00081: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2921 - accuracy: 0.9204
# Epoch 82/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2888 - accuracy: 0.9203
# Epoch 00082: loss did not improve from 0.28514
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2886 - accuracy: 0.9203
# Epoch 83/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2842 - accuracy: 0.9221
# Epoch 00083: loss improved from 0.28514 to 0.28420, saving model to /content/drive/MyDrive/weights-improvement-83-0.2842-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2842 - accuracy: 0.9221
# Epoch 84/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.9213
# Epoch 00084: loss did not improve from 0.28420
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2870 - accuracy: 0.9213
# Epoch 85/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2894 - accuracy: 0.9204
# Epoch 00085: loss did not improve from 0.28420
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2893 - accuracy: 0.9204
# Epoch 86/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2846 - accuracy: 0.9224
# Epoch 00086: loss did not improve from 0.28420
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2845 - accuracy: 0.9225
# Epoch 87/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.2801 - accuracy: 0.9236
# Epoch 00087: loss improved from 0.28420 to 0.28034, saving model to /content/drive/MyDrive/weights-improvement-87-0.2803-bigger.hdf5
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2803 - accuracy: 0.9235
# Epoch 88/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.9237
# Epoch 00088: loss improved from 0.28034 to 0.27830, saving model to /content/drive/MyDrive/weights-improvement-88-0.2783-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2783 - accuracy: 0.9237
# Epoch 89/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2880 - accuracy: 0.9215
# Epoch 00089: loss did not improve from 0.27830
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2880 - accuracy: 0.9215
# Epoch 90/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2840 - accuracy: 0.9215
# Epoch 00090: loss did not improve from 0.27830
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2840 - accuracy: 0.9215
# Epoch 91/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2897 - accuracy: 0.9210
# Epoch 00091: loss did not improve from 0.27830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2897 - accuracy: 0.9210
# Epoch 92/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2810 - accuracy: 0.9233
# Epoch 00092: loss did not improve from 0.27830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2809 - accuracy: 0.9234
# Epoch 93/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.9225
# Epoch 00093: loss did not improve from 0.27830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2861 - accuracy: 0.9225
# Epoch 94/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.9230
# Epoch 00094: loss did not improve from 0.27830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2811 - accuracy: 0.9230
# Epoch 95/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2808 - accuracy: 0.9228
# Epoch 00095: loss did not improve from 0.27830
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2807 - accuracy: 0.9228
# Epoch 96/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.9221
# Epoch 00096: loss did not improve from 0.27830
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2812 - accuracy: 0.9221
# Epoch 97/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2776 - accuracy: 0.9225
# Epoch 00097: loss improved from 0.27830 to 0.27780, saving model to /content/drive/MyDrive/weights-improvement-97-0.2778-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2778 - accuracy: 0.9225
# Epoch 98/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2783 - accuracy: 0.9230
# Epoch 00098: loss did not improve from 0.27780
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.2783 - accuracy: 0.9230
# Epoch 99/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2788 - accuracy: 0.9229
# Epoch 00099: loss did not improve from 0.27780
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2788 - accuracy: 0.9229
# Epoch 100/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.9222
# Epoch 00100: loss did not improve from 0.27780
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2845 - accuracy: 0.9222
# Epoch 101/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.2839 - accuracy: 0.9225
# Epoch 00101: loss did not improve from 0.27780
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2838 - accuracy: 0.9225
# Epoch 102/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2816 - accuracy: 0.9236
# Epoch 00102: loss did not improve from 0.27780
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2817 - accuracy: 0.9235
# Epoch 103/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9254
# Epoch 00103: loss improved from 0.27780 to 0.27247, saving model to /content/drive/MyDrive/weights-improvement-103-0.2725-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2725 - accuracy: 0.9254
# Epoch 104/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2790 - accuracy: 0.9226
# Epoch 00104: loss did not improve from 0.27247
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2789 - accuracy: 0.9226
# Epoch 105/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.9219
# Epoch 00105: loss did not improve from 0.27247
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2826 - accuracy: 0.9219
# Epoch 106/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2700 - accuracy: 0.9251
# Epoch 00106: loss improved from 0.27247 to 0.27004, saving model to /content/drive/MyDrive/weights-improvement-106-0.2700-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2700 - accuracy: 0.9251
# Epoch 107/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2790 - accuracy: 0.9226
# Epoch 00107: loss did not improve from 0.27004
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2790 - accuracy: 0.9225
# Epoch 108/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2783 - accuracy: 0.9229
# Epoch 00108: loss did not improve from 0.27004
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2784 - accuracy: 0.9229
# Epoch 109/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.9255
# Epoch 00109: loss improved from 0.27004 to 0.26910, saving model to /content/drive/MyDrive/weights-improvement-109-0.2691-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2691 - accuracy: 0.9255
# Epoch 110/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2782 - accuracy: 0.9239
# Epoch 00110: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2782 - accuracy: 0.9239
# Epoch 111/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2797 - accuracy: 0.9227
# Epoch 00111: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2798 - accuracy: 0.9227
# Epoch 112/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2798 - accuracy: 0.9228
# Epoch 00112: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2797 - accuracy: 0.9228
# Epoch 113/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2741 - accuracy: 0.9232
# Epoch 00113: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2742 - accuracy: 0.9232
# Epoch 114/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.9241
# Epoch 00114: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2727 - accuracy: 0.9241
# Epoch 115/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2739 - accuracy: 0.9235
# Epoch 00115: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2740 - accuracy: 0.9235
# Epoch 116/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2807 - accuracy: 0.9226
# Epoch 00116: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2806 - accuracy: 0.9226
# Epoch 117/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.9245
# Epoch 00117: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2737 - accuracy: 0.9245
# Epoch 118/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2739 - accuracy: 0.9240
# Epoch 00118: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2739 - accuracy: 0.9241
# Epoch 119/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.9253
# Epoch 00119: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2726 - accuracy: 0.9253
# Epoch 120/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.9240
# Epoch 00120: loss did not improve from 0.26910
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2769 - accuracy: 0.9240
# Epoch 121/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9261
# Epoch 00121: loss improved from 0.26910 to 0.26577, saving model to /content/drive/MyDrive/weights-improvement-121-0.2658-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2658 - accuracy: 0.9261
# Epoch 122/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9242
# Epoch 00122: loss did not improve from 0.26577
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2739 - accuracy: 0.9242
# Epoch 123/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2724 - accuracy: 0.9239
# Epoch 00123: loss did not improve from 0.26577
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2725 - accuracy: 0.9239
# Epoch 124/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2703 - accuracy: 0.9255
# Epoch 00124: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2702 - accuracy: 0.9255
# Epoch 125/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.2763 - accuracy: 0.9240
# Epoch 00125: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2769 - accuracy: 0.9239
# Epoch 126/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9239
# Epoch 00126: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2749 - accuracy: 0.9239
# Epoch 127/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.9258
# Epoch 00127: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2693 - accuracy: 0.9258
# Epoch 128/200
# 1567/1569 [============================>.] - ETA: 0s - loss: 0.2729 - accuracy: 0.9253
# Epoch 00128: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2729 - accuracy: 0.9253
# Epoch 129/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2707 - accuracy: 0.9257
# Epoch 00129: loss did not improve from 0.26577
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2707 - accuracy: 0.9257
# Epoch 130/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2718 - accuracy: 0.9247
# Epoch 00130: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2717 - accuracy: 0.9248
# Epoch 131/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2751 - accuracy: 0.9250
# Epoch 00131: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2751 - accuracy: 0.9250
# Epoch 132/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2701 - accuracy: 0.9248
# Epoch 00132: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2701 - accuracy: 0.9248
# Epoch 133/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2700 - accuracy: 0.9252
# Epoch 00133: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2700 - accuracy: 0.9252
# Epoch 134/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2723 - accuracy: 0.9252
# Epoch 00134: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2723 - accuracy: 0.9252
# Epoch 135/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2752 - accuracy: 0.9244
# Epoch 00135: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2751 - accuracy: 0.9244
# Epoch 136/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2730 - accuracy: 0.9229
# Epoch 00136: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2732 - accuracy: 0.9229
# Epoch 137/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.9250
# Epoch 00137: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2699 - accuracy: 0.9250
# Epoch 138/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2708 - accuracy: 0.9245
# Epoch 00138: loss did not improve from 0.26577
# 1569/1569 [==============================] - 40s 25ms/step - loss: 0.2708 - accuracy: 0.9246
# Epoch 139/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9263
# Epoch 00139: loss improved from 0.26577 to 0.26232, saving model to /content/drive/MyDrive/weights-improvement-139-0.2623-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2623 - accuracy: 0.9263
# Epoch 140/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2631 - accuracy: 0.9270
# Epoch 00140: loss did not improve from 0.26232
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2632 - accuracy: 0.9270
# Epoch 141/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2613 - accuracy: 0.9281
# Epoch 00141: loss improved from 0.26232 to 0.26133, saving model to /content/drive/MyDrive/weights-improvement-141-0.2613-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2613 - accuracy: 0.9280
# Epoch 142/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2668 - accuracy: 0.9268
# Epoch 00142: loss did not improve from 0.26133
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2667 - accuracy: 0.9268
# Epoch 143/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.9257
# Epoch 00143: loss did not improve from 0.26133
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2622 - accuracy: 0.9257
# Epoch 144/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2663 - accuracy: 0.9258
# Epoch 00144: loss did not improve from 0.26133
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2663 - accuracy: 0.9258
# Epoch 145/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9263
# Epoch 00145: loss did not improve from 0.26133
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2670 - accuracy: 0.9263
# Epoch 146/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2666 - accuracy: 0.9275
# Epoch 00146: loss did not improve from 0.26133
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2666 - accuracy: 0.9275
# Epoch 147/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2664 - accuracy: 0.9253
# Epoch 00147: loss did not improve from 0.26133
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2663 - accuracy: 0.9253
# Epoch 148/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2711 - accuracy: 0.9261
# Epoch 00148: loss did not improve from 0.26133
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2713 - accuracy: 0.9260
# Epoch 149/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2677 - accuracy: 0.9256
# Epoch 00149: loss did not improve from 0.26133
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2678 - accuracy: 0.9256
# Epoch 150/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2654 - accuracy: 0.9267
# Epoch 00150: loss did not improve from 0.26133
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2654 - accuracy: 0.9267
# Epoch 151/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2563 - accuracy: 0.9285
# Epoch 00151: loss improved from 0.26133 to 0.25627, saving model to /content/drive/MyDrive/weights-improvement-151-0.2563-bigger.hdf5
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2563 - accuracy: 0.9285
# Epoch 152/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2669 - accuracy: 0.9271
# Epoch 00152: loss did not improve from 0.25627
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2669 - accuracy: 0.9271
# Epoch 153/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.9283
# Epoch 00153: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 26ms/step - loss: 0.2617 - accuracy: 0.9283
# Epoch 154/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9268
# Epoch 00154: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2661 - accuracy: 0.9268
# Epoch 155/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.9280
# Epoch 00155: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2625 - accuracy: 0.9280
# Epoch 156/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2693 - accuracy: 0.9258
# Epoch 00156: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2692 - accuracy: 0.9259
# Epoch 157/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9263
# Epoch 00157: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2664 - accuracy: 0.9263
# Epoch 158/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2633 - accuracy: 0.9279
# Epoch 00158: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2633 - accuracy: 0.9279
# Epoch 159/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2621 - accuracy: 0.9275
# Epoch 00159: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2621 - accuracy: 0.9275
# Epoch 160/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9259
# Epoch 00160: loss did not improve from 0.25627
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2663 - accuracy: 0.9259
# Epoch 161/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2587 - accuracy: 0.9287
# Epoch 00161: loss did not improve from 0.25627
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2587 - accuracy: 0.9287
# Epoch 162/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2684 - accuracy: 0.9258
# Epoch 00162: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2685 - accuracy: 0.9258
# Epoch 163/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9267
# Epoch 00163: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2636 - accuracy: 0.9267
# Epoch 164/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2654 - accuracy: 0.9265
# Epoch 00164: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2654 - accuracy: 0.9265
# Epoch 165/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.9274
# Epoch 00165: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 28ms/step - loss: 0.2632 - accuracy: 0.9274
# Epoch 166/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2607 - accuracy: 0.9282
# Epoch 00166: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2607 - accuracy: 0.9282
# Epoch 167/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9277
# Epoch 00167: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2623 - accuracy: 0.9277
# Epoch 168/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2651 - accuracy: 0.9268
# Epoch 00168: loss did not improve from 0.25627
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2651 - accuracy: 0.9268
# Epoch 169/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2600 - accuracy: 0.9277
# Epoch 00169: loss did not improve from 0.25627
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2600 - accuracy: 0.9277
# Epoch 170/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2575 - accuracy: 0.9291
# Epoch 00170: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2575 - accuracy: 0.9291
# Epoch 171/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2650 - accuracy: 0.9259
# Epoch 00171: loss did not improve from 0.25627
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2650 - accuracy: 0.9259
# Epoch 172/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2643 - accuracy: 0.9264
# Epoch 00172: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2643 - accuracy: 0.9264
# Epoch 173/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2573 - accuracy: 0.9277
# Epoch 00173: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2574 - accuracy: 0.9277
# Epoch 174/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2587 - accuracy: 0.9290
# Epoch 00174: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2586 - accuracy: 0.9290
# Epoch 175/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9279
# Epoch 00175: loss did not improve from 0.25627
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2641 - accuracy: 0.9279
# Epoch 176/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2616 - accuracy: 0.9274
# Epoch 00176: loss did not improve from 0.25627
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2615 - accuracy: 0.9274
# Epoch 177/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2626 - accuracy: 0.9279
# Epoch 00177: loss did not improve from 0.25627
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2625 - accuracy: 0.9279
# Epoch 178/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9269
# Epoch 00178: loss did not improve from 0.25627
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2626 - accuracy: 0.9269
# Epoch 179/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2536 - accuracy: 0.9296
# Epoch 00179: loss improved from 0.25627 to 0.25354, saving model to /content/drive/MyDrive/weights-improvement-179-0.2535-bigger.hdf5
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2535 - accuracy: 0.9297
# Epoch 180/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.9284
# Epoch 00180: loss did not improve from 0.25354
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2559 - accuracy: 0.9284
# Epoch 181/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2595 - accuracy: 0.9294
# Epoch 00181: loss did not improve from 0.25354
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2594 - accuracy: 0.9294
# Epoch 182/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9283
# Epoch 00182: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2609 - accuracy: 0.9283
# Epoch 183/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9264
# Epoch 00183: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2687 - accuracy: 0.9264
# Epoch 184/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2609 - accuracy: 0.9272
# Epoch 00184: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2610 - accuracy: 0.9271
# Epoch 185/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2574 - accuracy: 0.9277
# Epoch 00185: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2574 - accuracy: 0.9277
# Epoch 186/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2584 - accuracy: 0.9282
# Epoch 00186: loss did not improve from 0.25354
# 1569/1569 [==============================] - 41s 26ms/step - loss: 0.2584 - accuracy: 0.9282
# Epoch 187/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2569 - accuracy: 0.9288
# Epoch 00187: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2568 - accuracy: 0.9288
# Epoch 188/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.9300
# Epoch 00188: loss did not improve from 0.25354
# 1569/1569 [==============================] - 43s 27ms/step - loss: 0.2548 - accuracy: 0.9300
# Epoch 189/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.9274
# Epoch 00189: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2630 - accuracy: 0.9274
# Epoch 190/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2583 - accuracy: 0.9283
# Epoch 00190: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2584 - accuracy: 0.9282
# Epoch 191/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2612 - accuracy: 0.9272
# Epoch 00191: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2613 - accuracy: 0.9272
# Epoch 192/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2541 - accuracy: 0.9294
# Epoch 00192: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2541 - accuracy: 0.9294
# Epoch 193/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2556 - accuracy: 0.9285
# Epoch 00193: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2557 - accuracy: 0.9284
# Epoch 194/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2556 - accuracy: 0.9283
# Epoch 00194: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2555 - accuracy: 0.9283
# Epoch 195/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.9293
# Epoch 00195: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2568 - accuracy: 0.9293
# Epoch 196/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2626 - accuracy: 0.9273
# Epoch 00196: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2625 - accuracy: 0.9273
# Epoch 197/200
# 1568/1569 [============================>.] - ETA: 0s - loss: 0.2560 - accuracy: 0.9286
# Epoch 00197: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2561 - accuracy: 0.9286
# Epoch 198/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9286
# Epoch 00198: loss did not improve from 0.25354
# 1569/1569 [==============================] - 40s 26ms/step - loss: 0.2593 - accuracy: 0.9286
# Epoch 199/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9284
# Epoch 00199: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2589 - accuracy: 0.9284
# Epoch 200/200
# 1569/1569 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9279
# Epoch 00200: loss did not improve from 0.25354
# 1569/1569 [==============================] - 42s 27ms/step - loss: 0.2594 - accuracy: 0.9279

# %%
seed_text = "россия"
next_words = 11

# %%
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length - 1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word

# %%
seed_text
# Out:
# 'россия надеется что западные страны не будут пытаться необъективно оценивать предстоящие парламентские'

# %%
/content/drive/MyDrive/Grocery2018_rus.pdf

# %%
model.save('/content/drive/MyDrive/textgenerationmodel.h5')
